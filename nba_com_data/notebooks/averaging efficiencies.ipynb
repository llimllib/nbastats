# %%
from functools import reduce
from typing import List

from nba_api.stats.endpoints import (
    LeagueDashPlayerStats,
    LeagueDashPlayerBioStats,
    TeamGameLogs,
)
import pandas as pd
import math

# %%
df = pd.read_parquet("data/gamelog_2023.parquet")
print(df.iloc[0].to_markdown())
# Out:
# |                   | 0                   |
# |:------------------|:--------------------|
# | game_n            | 0                   |
# | SEASON_YEAR       | 2022-23             |
# | TEAM_ID           | 1610612746          |
# | TEAM_ABBREVIATION | LAC                 |
# | TEAM_NAME         | LA Clippers         |
# | GAME_ID           | 0022200207          |
# | GAME_DATE         | 2022-11-15T00:00:00 |
# | MATCHUP           | LAC @ DAL           |
# | WL                | L                   |
# | MIN               | 48.0                |
# | FGM               | 34                  |
# | FGA               | 64                  |
# | FG_PCT            | 0.531               |
# | FG3M              | 12                  |
# | FG3A              | 28                  |
# | FG3_PCT           | 0.429               |
# | FTM               | 21                  |
# | FTA               | 26                  |
# | FT_PCT            | 0.808               |
# | OREB              | 3                   |
# | DREB              | 37                  |
# | REB               | 40                  |
# | AST               | 23                  |
# | TOV               | 21.0                |
# | STL               | 8                   |
# | BLK               | 2                   |
# | BLKA              | 1                   |
# | PF                | 27                  |
# | PFD               | 20                  |
# | PTS               | 101                 |
# | PLUS_MINUS        | -2.0                |
# | GP_RANK           | 1                   |
# | W_RANK            | 210                 |
# | L_RANK            | 210                 |
# | W_PCT_RANK        | 210                 |
# | MIN_RANK          | 35                  |
# | FGM_RANK          | 387                 |
# | FGA_RANK          | 418                 |
# | FG_PCT_RANK       | 46                  |
# | FG3M_RANK         | 178                 |
# | FG3A_RANK         | 340                 |
# | FG3_PCT_RANK      | 83                  |
# | FTM_RANK          | 112                 |
# | FTA_RANK          | 124                 |
# | FT_PCT_RANK       | 175                 |
# | OREB_RANK         | 411                 |
# | DREB_RANK         | 85                  |
# | REB_RANK          | 286                 |
# | AST_RANK          | 249                 |
# | TOV_RANK          | 389                 |
# | STL_RANK          | 143                 |
# | BLK_RANK          | 351                 |
# | BLKA_RANK         | 6                   |
# | PF_RANK           | 384                 |
# | PFD_RANK          | 225                 |
# | PTS_RANK          | 354                 |
# | PLUS_MINUS_RANK   | 216                 |
# | E_OFF_RATING      | 108.1               |
# | OFF_RATING        | 106.3               |
# | E_DEF_RATING      | 108.9               |
# | DEF_RATING        | 109.6               |
# | E_NET_RATING      | -0.8                |
# | NET_RATING        | -3.3                |
# | AST_PCT           | 0.676               |
# | AST_TO            | 1.1                 |
# | AST_RATIO         | 18.9                |
# | OREB_PCT          | 0.121               |
# | DREB_PCT          | 0.824               |
# | REB_PCT           | 0.548               |
# | TM_TOV_PCT        | 0.221               |
# | EFG_PCT           | 0.625               |
# | TS_PCT            | 0.669               |
# | E_PACE            | 94.0                |
# | PACE              | 94.5                |
# | PACE_PER40        | 78.75               |
# | POSS              | 95                  |
# | PIE               | 0.524               |
# | OFF_RATING_RANK   | 292                 |
# | DEF_RATING_RANK   | 173                 |
# | NET_RATING_RANK   | 239                 |
# | AST_PCT_RANK      | 101                 |
# | AST_TO_RANK       | 380                 |
# | AST_RATIO_RANK    | 153                 |
# | OREB_PCT_RANK     | 418                 |
# | DREB_PCT_RANK     | 30                  |
# | REB_PCT_RANK      | 61                  |
# | TM_TOV_PCT_RANK   | 410                 |
# | EFG_PCT_RANK      | 34                  |
# | TS_PCT_RANK       | 19                  |
# | PACE_RANK         | 375                 |
# | PIE_RANK          | 167                 |

# %%
eff = df[["TEAM_ABBREVIATION", "GAME_DATE", "MATCHUP", "OFF_RATING", "DEF_RATING", "PTS", "POSS"]]

# %%
eff
# Out:
#     TEAM_ABBREVIATION            GAME_DATE      MATCHUP  OFF_RATING  \
# 0                 LAC  2022-11-15T00:00:00    LAC @ DAL       106.3
# 1                 SAC  2022-11-15T00:00:00  SAC vs. BKN       140.4
# 2                 UTA  2022-11-15T00:00:00  UTA vs. NYK       107.8
# 3                 SAS  2022-11-15T00:00:00    SAS @ POR       112.2
# 4                 BKN  2022-11-15T00:00:00    BKN @ SAC       111.0
# ..                ...                  ...          ...         ...
# 469               IND  2022-11-16T00:00:00    IND @ CHA       120.2
# 470               NOP  2022-11-16T00:00:00  NOP vs. CHI       126.5
# 471               MIL  2022-11-16T00:00:00  MIL vs. CLE       120.2
# 472               MIN  2022-11-16T00:00:00    MIN @ ORL       124.8
# 473               BOS  2022-11-16T00:00:00    BOS @ ATL       124.8
#
#      DEF_RATING  PTS  POSS
# 0         109.6  101    95
# 1         111.0  153   109
# 2         114.6  111   103
# 3         120.6  110    98
# 4         140.4  121   109
# ..          ...  ...   ...
# 469       107.6  125   104
# 470       111.1  124    98
# 471       103.2  113    94
# 472       106.9  126   101
# 473        98.1  126   101
#
# [474 rows x 7 columns]

# %%
eff.loc[eff["TEAM_ABBREVIATION"] == "BOS"]
# Out:
#     TEAM_ABBREVIATION            GAME_DATE      MATCHUP  OFF_RATING  \
# 20                BOS  2022-11-14T00:00:00  BOS vs. OKC       112.5
# 40                BOS  2022-11-12T00:00:00    BOS @ DET       119.4
# 64                BOS  2022-11-11T00:00:00  BOS vs. DEN       140.9
# 86                BOS  2022-11-09T00:00:00  BOS vs. DET       125.5
# 113               BOS  2022-11-07T00:00:00    BOS @ MEM       110.1
# 148               BOS  2022-11-05T00:00:00    BOS @ NYK       135.7
# 162               BOS  2022-11-04T00:00:00  BOS vs. CHI       119.4
# 186               BOS  2022-11-02T00:00:00    BOS @ CLE       102.7
# 233               BOS  2022-10-30T00:00:00  BOS vs. WAS       115.5
# 278               BOS  2022-10-28T00:00:00  BOS vs. CLE       112.8
# 319               BOS  2022-10-24T00:00:00    BOS @ CHI       101.0
# 350               BOS  2022-10-22T00:00:00    BOS @ ORL       126.0
# 376               BOS  2022-10-21T00:00:00    BOS @ MIA       116.8
# 416               BOS  2022-10-18T00:00:00  BOS vs. PHI       129.9
# 437               BOS  2022-11-16T00:00:00    BOS @ ATL       124.8
# 473               BOS  2022-11-16T00:00:00    BOS @ ATL       124.8
#
#      DEF_RATING  PTS
# 20        108.0  126
# 40        109.1  117
# 64        120.4  131
# 86        109.8  128
# 113       105.0  109
# 148       119.2  133
# 162       114.4  123
# 186       103.6  113
# 233        96.9  112
# 278       121.1  123
# 319       117.6  102
# 350       121.2  126
# 376       109.5  111
# 416       119.4  126
# 437        98.1  126
# 473        98.1  126

# %%
# so in game 20, we had 126 and an ORTG of 112.5
# ORTG = 100 * (pts / poss) -> ORTG/100 = pts / poss -> (ORTG/100) * poss = pts -> pts / (ORTG/100) = poss
# so this game has 112 possessions
126/(112.5/100)
# Out:
# 112.0

# %%
# off_rating is truncated, so we can round this value to get the true value
df["poss"] = round(df["PTS"] / (df["OFF_RATING"] / 100))
df
# Out:
#      game_n SEASON_YEAR     TEAM_ID TEAM_ABBREVIATION               TEAM_NAME  \
# 0         0     2022-23  1610612746               LAC             LA Clippers
# 1         1     2022-23  1610612758               SAC        Sacramento Kings
# 2         2     2022-23  1610612762               UTA               Utah Jazz
# 3         3     2022-23  1610612759               SAS       San Antonio Spurs
# 4         4     2022-23  1610612751               BKN           Brooklyn Nets
# ..      ...         ...         ...               ...                     ...
# 469      21     2022-23  1610612754               IND          Indiana Pacers
# 470      22     2022-23  1610612740               NOP    New Orleans Pelicans
# 471      23     2022-23  1610612749               MIL         Milwaukee Bucks
# 472      24     2022-23  1610612750               MIN  Minnesota Timberwolves
# 473      25     2022-23  1610612738               BOS          Boston Celtics
#
#         GAME_ID            GAME_DATE      MATCHUP WL   MIN  ...  \
# 0    0022200207  2022-11-15T00:00:00    LAC @ DAL  L  48.0  ...
# 1    0022200210  2022-11-15T00:00:00  SAC vs. BKN  W  48.0  ...
# 2    0022200208  2022-11-15T00:00:00  UTA vs. NYK  L  48.0  ...
# 3    0022200209  2022-11-15T00:00:00    SAS @ POR  L  48.0  ...
# 4    0022200210  2022-11-15T00:00:00    BKN @ SAC  L  48.0  ...
# ..          ...                  ...          ... ..   ...  ...
# 469  0022200211  2022-11-16T00:00:00    IND @ CHA  W  48.0  ...
# 470  0022200217  2022-11-16T00:00:00  NOP vs. CHI  W  48.0  ...
# 471  0022200216  2022-11-16T00:00:00  MIL vs. CLE  W  48.0  ...
# 472  0022200212  2022-11-16T00:00:00    MIN @ ORL  W  48.0  ...
# 473  0022200214  2022-11-16T00:00:00    BOS @ ATL  W  48.0  ...
#
#      AST_RATIO_RANK  OREB_PCT_RANK  DREB_PCT_RANK  REB_PCT_RANK  \
# 0               153            418             30            61
# 1                 5             89              4             8
# 2               118            111            294           183
# 3                 9            199            184           237
# 4               201            417            332           413
# ..              ...            ...            ...           ...
# 469              10             20             24            23
# 470               6              4             12             5
# 471              14              2              1             1
# 472               9             19             22            19
# 473               4             25             16            13
#
#      TM_TOV_PCT_RANK  EFG_PCT_RANK  TS_PCT_RANK  PACE_RANK  PIE_RANK   poss
# 0                410            34           19        375       167   95.0
# 1                256             4            3         13        27  109.0
# 2                396           251          198         91       214  103.0
# 3                368           125          145        297       231   98.0
# 4                256           140           69         13       394  109.0
# ..               ...           ...          ...        ...       ...    ...
# 469               10             9            6          3         8  104.0
# 470               16             8            7         15         5   98.0
# 471               13            12           15         21        10   94.0
# 472                6            10            9          7         2  101.0
# 473               11             1            3          5         3  101.0
#
# [474 rows x 92 columns]

# %%
# now that we have possessions, we can accurately sum and average the values
teameff = df[["TEAM_ABBREVIATION", "GAME_DATE", "MATCHUP", "OFF_RATING", "DEF_RATING", "PTS", "poss"]]
teameff.to_dict(orient="records")
# Out:
# [{'TEAM_ABBREVIATION': 'LAC',
#   'GAME_DATE': '2022-11-15T00:00:00',
#   'MATCHUP': 'LAC @ DAL',
#   'OFF_RATING': 106.3,
#   'DEF_RATING': 109.6,
#   'PTS': 101,
#   'poss': 95.0},
#  {'TEAM_ABBREVIATION': 'SAC',
#   'GAME_DATE': '2022-11-15T00:00:00',
#   'MATCHUP': 'SAC vs. BKN',
#   'OFF_RATING': 140.4,
#   'DEF_RATING': 111.0,
#   'PTS': 153,
#   'poss': 109.0},
#  {'TEAM_ABBREVIATION': 'UTA',
#   'GAME_DATE': '2022-11-15T00:00:00',
#   'MATCHUP': 'UTA vs. NYK',
#   'OFF_RATING': 107.8,
#   'DEF_RATING': 114.6,
#   'PTS': 111,
#   'poss': 103.0},
#  {'TEAM_ABBREVIATION': 'SAS',
#   'GAME_DATE': '2022-11-15T00:00:00',
#   'MATCHUP': 'SAS @ POR',
#   'OFF_RATING': 112.2,
#   'DEF_RATING': 120.6,
#   'PTS': 110,
#   'poss': 98.0},
#  {'TEAM_ABBREVIATION': 'BKN',
#   'GAME_DATE': '2022-11-15T00:00:00',
#   'MATCHUP': 'BKN @ SAC',
#   'OFF_RATING': 111.0,
#   'DEF_RATING': 140.4,
#   'PTS': 121,
#   'poss': 109.0},
#  {'TEAM_ABBREVIATION': 'NOP',
#   'GAME_DATE': '2022-11-15T00:00:00',
#   'MATCHUP': 'NOP vs. MEM',
#   'OFF_RATING': 115.3,
#   'DEF_RATING': 103.0,
#   'PTS': 113,
#   'poss': 98.0},
#  {'TEAM_ABBREVIATION': 'MEM',
#   'GAME_DATE': '2022-11-15T00:00:00',
#   'MATCHUP': 'MEM @ NOP',
#   'OFF_RATING': 103.0,
#   'DEF_RATING': 115.3,
#   'PTS': 102,
#   'poss': 99.0},
#  {'TEAM_ABBREVIATION': 'POR',
#   'GAME_DATE': '2022-11-15T00:00:00',
#   'MATCHUP': 'POR vs. SAS',
#   'OFF_RATING': 120.6,
#   'DEF_RATING': 112.2,
#   'PTS': 117,
#   'poss': 97.0},
#  {'TEAM_ABBREVIATION': 'NYK',
#   'GAME_DATE': '2022-11-15T00:00:00',
#   'MATCHUP': 'NYK @ UTA',
#   'OFF_RATING': 114.6,
#   'DEF_RATING': 107.8,
#   'PTS': 118,
#   'poss': 103.0},
#  {'TEAM_ABBREVIATION': 'DAL',
#   'GAME_DATE': '2022-11-15T00:00:00',
#   'MATCHUP': 'DAL vs. LAC',
#   'OFF_RATING': 109.6,
#   'DEF_RATING': 106.3,
#   'PTS': 103,
#   'poss': 94.0},
#  {'TEAM_ABBREVIATION': 'HOU',
#   'GAME_DATE': '2022-11-14T00:00:00',
#   'MATCHUP': 'HOU vs. LAC',
#   'OFF_RATING': 105.0,
#   'DEF_RATING': 120.8,
#   'PTS': 106,
#   'poss': 101.0},
#  {'TEAM_ABBREVIATION': 'MIL',
#   'GAME_DATE': '2022-11-14T00:00:00',
#   'MATCHUP': 'MIL vs. ATL',
#   'OFF_RATING': 103.9,
#   'DEF_RATING': 119.8,
#   'PTS': 106,
#   'poss': 102.0},
#  {'TEAM_ABBREVIATION': 'LAC',
#   'GAME_DATE': '2022-11-14T00:00:00',
#   'MATCHUP': 'LAC @ HOU',
#   'OFF_RATING': 120.8,
#   'DEF_RATING': 105.0,
#   'PTS': 122,
#   'poss': 101.0},
#  {'TEAM_ABBREVIATION': 'DET',
#   'GAME_DATE': '2022-11-14T00:00:00',
#   'MATCHUP': 'DET vs. TOR',
#   'OFF_RATING': 111.0,
#   'DEF_RATING': 116.2,
#   'PTS': 111,
#   'poss': 100.0},
#  {'TEAM_ABBREVIATION': 'ATL',
#   'GAME_DATE': '2022-11-14T00:00:00',
#   'MATCHUP': 'ATL @ MIL',
#   'OFF_RATING': 119.8,
#   'DEF_RATING': 103.9,
#   'PTS': 121,
#   'poss': 101.0},
#  {'TEAM_ABBREVIATION': 'OKC',
#   'GAME_DATE': '2022-11-14T00:00:00',
#   'MATCHUP': 'OKC @ BOS',
#   'OFF_RATING': 108.0,
#   'DEF_RATING': 112.5,
#   'PTS': 122,
#   'poss': 113.0},
#  {'TEAM_ABBREVIATION': 'CHA',
#   'GAME_DATE': '2022-11-14T00:00:00',
#   'MATCHUP': 'CHA @ ORL',
#   'OFF_RATING': 116.7,
#   'DEF_RATING': 110.5,
#   'PTS': 112,
#   'poss': 96.0},
#  {'TEAM_ABBREVIATION': 'PHX',
#   'GAME_DATE': '2022-11-14T00:00:00',
#   'MATCHUP': 'PHX @ MIA',
#   'OFF_RATING': 123.1,
#   'DEF_RATING': 124.2,
#   'PTS': 112,
#   'poss': 91.0},
#  {'TEAM_ABBREVIATION': 'TOR',
#   'GAME_DATE': '2022-11-14T00:00:00',
#   'MATCHUP': 'TOR @ DET',
#   'OFF_RATING': 116.2,
#   'DEF_RATING': 111.0,
#   'PTS': 115,
#   'poss': 99.0},
#  {'TEAM_ABBREVIATION': 'ORL',
#   'GAME_DATE': '2022-11-14T00:00:00',
#   'MATCHUP': 'ORL vs. CHA',
#   'OFF_RATING': 110.5,
#   'DEF_RATING': 116.7,
#   'PTS': 105,
#   'poss': 95.0},
#  {'TEAM_ABBREVIATION': 'BOS',
#   'GAME_DATE': '2022-11-14T00:00:00',
#   'MATCHUP': 'BOS vs. OKC',
#   'OFF_RATING': 112.5,
#   'DEF_RATING': 108.0,
#   'PTS': 126,
#   'poss': 112.0},
#  {'TEAM_ABBREVIATION': 'GSW',
#   'GAME_DATE': '2022-11-14T00:00:00',
#   'MATCHUP': 'GSW vs. SAS',
#   'OFF_RATING': 130.7,
#   'DEF_RATING': 94.1,
#   'PTS': 132,
#   'poss': 101.0},
#  {'TEAM_ABBREVIATION': 'SAS',
#   'GAME_DATE': '2022-11-14T00:00:00',
#   'MATCHUP': 'SAS @ GSW',
#   'OFF_RATING': 94.1,
#   'DEF_RATING': 130.7,
#   'PTS': 95,
#   'poss': 101.0},
#  {'TEAM_ABBREVIATION': 'MIA',
#   'GAME_DATE': '2022-11-14T00:00:00',
#   'MATCHUP': 'MIA vs. PHX',
#   'OFF_RATING': 124.2,
#   'DEF_RATING': 123.1,
#   'PTS': 113,
#   'poss': 91.0},
#  {'TEAM_ABBREVIATION': 'MEM',
#   'GAME_DATE': '2022-11-13T00:00:00',
#   'MATCHUP': 'MEM @ WAS',
#   'OFF_RATING': 92.9,
#   'DEF_RATING': 102.0,
#   'PTS': 92,
#   'poss': 99.0},
#  {'TEAM_ABBREVIATION': 'MIN',
#   'GAME_DATE': '2022-11-13T00:00:00',
#   'MATCHUP': 'MIN @ CLE',
#   'OFF_RATING': 130.3,
#   'DEF_RATING': 122.8,
#   'PTS': 129,
#   'poss': 99.0},
#  {'TEAM_ABBREVIATION': 'SAC',
#   'GAME_DATE': '2022-11-13T00:00:00',
#   'MATCHUP': 'SAC vs. GSW',
#   'OFF_RATING': 117.3,
#   'DEF_RATING': 110.6,
#   'PTS': 122,
#   'poss': 104.0},
#  {'TEAM_ABBREVIATION': 'NYK',
#   'GAME_DATE': '2022-11-13T00:00:00',
#   'MATCHUP': 'NYK vs. OKC',
#   'OFF_RATING': 125.0,
#   'DEF_RATING': 133.0,
#   'PTS': 135,
#   'poss': 108.0},
#  {'TEAM_ABBREVIATION': 'CLE',
#   'GAME_DATE': '2022-11-13T00:00:00',
#   'MATCHUP': 'CLE vs. MIN',
#   'OFF_RATING': 122.8,
#   'DEF_RATING': 130.3,
#   'PTS': 124,
#   'poss': 101.0},
#  {'TEAM_ABBREVIATION': 'PHI',
#   'GAME_DATE': '2022-11-13T00:00:00',
#   'MATCHUP': 'PHI vs. UTA',
#   'OFF_RATING': 107.1,
#   'DEF_RATING': 101.0,
#   'PTS': 105,
#   'poss': 98.0},
#  {'TEAM_ABBREVIATION': 'LAL',
#   'GAME_DATE': '2022-11-13T00:00:00',
#   'MATCHUP': 'LAL vs. BKN',
#   'OFF_RATING': 120.8,
#   'DEF_RATING': 108.4,
#   'PTS': 116,
#   'poss': 96.0},
#  {'TEAM_ABBREVIATION': 'WAS',
#   'GAME_DATE': '2022-11-13T00:00:00',
#   'MATCHUP': 'WAS vs. MEM',
#   'OFF_RATING': 102.0,
#   'DEF_RATING': 92.9,
#   'PTS': 102,
#   'poss': 100.0},
#  {'TEAM_ABBREVIATION': 'OKC',
#   'GAME_DATE': '2022-11-13T00:00:00',
#   'MATCHUP': 'OKC @ NYK',
#   'OFF_RATING': 133.0,
#   'DEF_RATING': 125.0,
#   'PTS': 145,
#   'poss': 109.0},
#  {'TEAM_ABBREVIATION': 'BKN',
#   'GAME_DATE': '2022-11-13T00:00:00',
#   'MATCHUP': 'BKN @ LAL',
#   'OFF_RATING': 108.4,
#   'DEF_RATING': 120.8,
#   'PTS': 103,
#   'poss': 95.0},
#  {'TEAM_ABBREVIATION': 'GSW',
#   'GAME_DATE': '2022-11-13T00:00:00',
#   'MATCHUP': 'GSW @ SAC',
#   'OFF_RATING': 110.6,
#   'DEF_RATING': 117.3,
#   'PTS': 115,
#   'poss': 104.0},
#  {'TEAM_ABBREVIATION': 'DEN',
#   'GAME_DATE': '2022-11-13T00:00:00',
#   'MATCHUP': 'DEN @ CHI',
#   'OFF_RATING': 126.0,
#   'DEF_RATING': 102.0,
#   'PTS': 126,
#   'poss': 100.0},
#  {'TEAM_ABBREVIATION': 'CHI',
#   'GAME_DATE': '2022-11-13T00:00:00',
#   'MATCHUP': 'CHI vs. DEN',
#   'OFF_RATING': 102.0,
#   'DEF_RATING': 126.0,
#   'PTS': 103,
#   'poss': 101.0},
#  {'TEAM_ABBREVIATION': 'UTA',
#   'GAME_DATE': '2022-11-13T00:00:00',
#   'MATCHUP': 'UTA @ PHI',
#   'OFF_RATING': 101.0,
#   'DEF_RATING': 107.1,
#   'PTS': 98,
#   'poss': 97.0},
#  {'TEAM_ABBREVIATION': 'NOP',
#   'GAME_DATE': '2022-11-12T00:00:00',
#   'MATCHUP': 'NOP vs. HOU',
#   'OFF_RATING': 117.8,
#   'DEF_RATING': 105.0,
#   'PTS': 119,
#   'poss': 101.0},
#  {'TEAM_ABBREVIATION': 'DET',
#   'GAME_DATE': '2022-11-12T00:00:00',
#   'MATCHUP': 'DET vs. BOS',
#   'OFF_RATING': 109.1,
#   'DEF_RATING': 119.4,
#   'PTS': 108,
#   'poss': 99.0},
#  {'TEAM_ABBREVIATION': 'BOS',
#   'GAME_DATE': '2022-11-12T00:00:00',
#   'MATCHUP': 'BOS @ DET',
#   'OFF_RATING': 119.4,
#   'DEF_RATING': 109.1,
#   'PTS': 117,
#   'poss': 98.0},
#  {'TEAM_ABBREVIATION': 'ATL',
#   'GAME_DATE': '2022-11-12T00:00:00',
#   'MATCHUP': 'ATL @ PHI',
#   'OFF_RATING': 107.9,
#   'DEF_RATING': 119.8,
#   'PTS': 109,
#   'poss': 101.0},
#  {'TEAM_ABBREVIATION': 'DAL',
#   'GAME_DATE': '2022-11-12T00:00:00',
#   'MATCHUP': 'DAL vs. POR',
#   'OFF_RATING': 123.2,
#   'DEF_RATING': 117.9,
#   'PTS': 117,
#   'poss': 95.0},
#  {'TEAM_ABBREVIATION': 'IND',
#   'GAME_DATE': '2022-11-12T00:00:00',
#   'MATCHUP': 'IND vs. TOR',
#   'OFF_RATING': 115.7,
#   'DEF_RATING': 103.0,
#   'PTS': 118,
#   'poss': 102.0},
#  {'TEAM_ABBREVIATION': 'HOU',
#   'GAME_DATE': '2022-11-12T00:00:00',
#   'MATCHUP': 'HOU @ NOP',
#   'OFF_RATING': 105.0,
#   'DEF_RATING': 117.8,
#   'PTS': 106,
#   'poss': 101.0},
#  {'TEAM_ABBREVIATION': 'UTA',
#   'GAME_DATE': '2022-11-12T00:00:00',
#   'MATCHUP': 'UTA @ WAS',
#   'OFF_RATING': 110.9,
#   'DEF_RATING': 119.8,
#   'PTS': 112,
#   'poss': 101.0},
#  {'TEAM_ABBREVIATION': 'CHA',
#   'GAME_DATE': '2022-11-12T00:00:00',
#   'MATCHUP': 'CHA @ MIA',
#   'OFF_RATING': 112.7,
#   'DEF_RATING': 128.2,
#   'PTS': 115,
#   'poss': 102.0},
#  {'TEAM_ABBREVIATION': 'TOR',
#   'GAME_DATE': '2022-11-12T00:00:00',
#   'MATCHUP': 'TOR @ IND',
#   'OFF_RATING': 103.0,
#   'DEF_RATING': 115.7,
#   'PTS': 104,
#   'poss': 101.0},
#  {'TEAM_ABBREVIATION': 'BKN',
#   'GAME_DATE': '2022-11-12T00:00:00',
#   'MATCHUP': 'BKN @ LAC',
#   'OFF_RATING': 112.2,
#   'DEF_RATING': 96.9,
#   'PTS': 110,
#   'poss': 98.0},
#  {'TEAM_ABBREVIATION': 'PHI',
#   'GAME_DATE': '2022-11-12T00:00:00',
#   'MATCHUP': 'PHI vs. ATL',
#   'OFF_RATING': 119.8,
#   'DEF_RATING': 107.9,
#   'PTS': 121,
#   'poss': 101.0},
#  {'TEAM_ABBREVIATION': 'POR',
#   'GAME_DATE': '2022-11-12T00:00:00',
#   'MATCHUP': 'POR @ DAL',
#   'OFF_RATING': 117.9,
#   'DEF_RATING': 123.2,
#   'PTS': 112,
#   'poss': 95.0},
#  {'TEAM_ABBREVIATION': 'WAS',
#   'GAME_DATE': '2022-11-12T00:00:00',
#   'MATCHUP': 'WAS vs. UTA',
#   'OFF_RATING': 119.8,
#   'DEF_RATING': 110.9,
#   'PTS': 121,
#   'poss': 101.0},
#  {'TEAM_ABBREVIATION': 'LAC',
#   'GAME_DATE': '2022-11-12T00:00:00',
#   'MATCHUP': 'LAC vs. BKN',
#   'OFF_RATING': 96.9,
#   'DEF_RATING': 112.2,
#   'PTS': 95,
#   'poss': 98.0},
#  {'TEAM_ABBREVIATION': 'MIA',
#   'GAME_DATE': '2022-11-12T00:00:00',
#   'MATCHUP': 'MIA vs. CHA',
#   'OFF_RATING': 128.2,
#   'DEF_RATING': 112.7,
#   'PTS': 132,
#   'poss': 103.0},
#  {'TEAM_ABBREVIATION': 'SAC',
#   'GAME_DATE': '2022-11-11T00:00:00',
#   'MATCHUP': 'SAC @ LAL',
#   'OFF_RATING': 120.0,
#   'DEF_RATING': 115.2,
#   'PTS': 120,
#   'poss': 100.0},
#  {'TEAM_ABBREVIATION': 'MIN',
#   'GAME_DATE': '2022-11-11T00:00:00',
#   'MATCHUP': 'MIN @ MEM',
#   'OFF_RATING': 109.6,
#   'DEF_RATING': 120.0,
#   'PTS': 103,
#   'poss': 94.0},
#  {'TEAM_ABBREVIATION': 'MIL',
#   'GAME_DATE': '2022-11-11T00:00:00',
#   'MATCHUP': 'MIL @ SAS',
#   'OFF_RATING': 95.9,
#   'DEF_RATING': 113.3,
#   'PTS': 93,
#   'poss': 97.0},
#  {'TEAM_ABBREVIATION': 'MEM',
#   'GAME_DATE': '2022-11-11T00:00:00',
#   'MATCHUP': 'MEM vs. MIN',
#   'OFF_RATING': 120.0,
#   'DEF_RATING': 109.6,
#   'PTS': 114,
#   'poss': 95.0},
#  {'TEAM_ABBREVIATION': 'DEN',
#   'GAME_DATE': '2022-11-11T00:00:00',
#   'MATCHUP': 'DEN @ BOS',
#   'OFF_RATING': 120.4,
#   'DEF_RATING': 140.9,
#   'PTS': 112,
#   'poss': 93.0},
#  {'TEAM_ABBREVIATION': 'TOR',
#   'GAME_DATE': '2022-11-11T00:00:00',
#   'MATCHUP': 'TOR @ OKC',
#   'OFF_RATING': 109.7,
#   'DEF_RATING': 126.9,
#   'PTS': 113,
#   'poss': 103.0},
#  {'TEAM_ABBREVIATION': 'GSW',
#   'GAME_DATE': '2022-11-11T00:00:00',
#   'MATCHUP': 'GSW vs. CLE',
#   'OFF_RATING': 108.2,
#   'DEF_RATING': 104.1,
#   'PTS': 106,
#   'poss': 98.0},
#  {'TEAM_ABBREVIATION': 'PHX',
#   'GAME_DATE': '2022-11-11T00:00:00',
#   'MATCHUP': 'PHX @ ORL',
#   'OFF_RATING': 104.3,
#   'DEF_RATING': 122.6,
#   'PTS': 97,
#   'poss': 93.0},
#  {'TEAM_ABBREVIATION': 'DET',
#   'GAME_DATE': '2022-11-11T00:00:00',
#   'MATCHUP': 'DET @ NYK',
#   'OFF_RATING': 112.0,
#   'DEF_RATING': 121.0,
#   'PTS': 112,
#   'poss': 100.0},
#  {'TEAM_ABBREVIATION': 'LAL',
#   'GAME_DATE': '2022-11-11T00:00:00',
#   'MATCHUP': 'LAL vs. SAC',
#   'OFF_RATING': 115.2,
#   'DEF_RATING': 120.0,
#   'PTS': 114,
#   'poss': 99.0},
#  {'TEAM_ABBREVIATION': 'BOS',
#   'GAME_DATE': '2022-11-11T00:00:00',
#   'MATCHUP': 'BOS vs. DEN',
#   'OFF_RATING': 140.9,
#   'DEF_RATING': 120.4,
#   'PTS': 131,
#   'poss': 93.0},
#  {'TEAM_ABBREVIATION': 'CLE',
#   'GAME_DATE': '2022-11-11T00:00:00',
#   'MATCHUP': 'CLE @ GSW',
#   'OFF_RATING': 104.1,
#   'DEF_RATING': 108.2,
#   'PTS': 101,
#   'poss': 97.0},
#  {'TEAM_ABBREVIATION': 'OKC',
#   'GAME_DATE': '2022-11-11T00:00:00',
#   'MATCHUP': 'OKC vs. TOR',
#   'OFF_RATING': 126.9,
#   'DEF_RATING': 109.7,
#   'PTS': 132,
#   'poss': 104.0},
#  {'TEAM_ABBREVIATION': 'ORL',
#   'GAME_DATE': '2022-11-11T00:00:00',
#   'MATCHUP': 'ORL vs. PHX',
#   'OFF_RATING': 122.6,
#   'DEF_RATING': 104.3,
#   'PTS': 114,
#   'poss': 93.0},
#  {'TEAM_ABBREVIATION': 'NYK',
#   'GAME_DATE': '2022-11-11T00:00:00',
#   'MATCHUP': 'NYK vs. DET',
#   'OFF_RATING': 121.0,
#   'DEF_RATING': 112.0,
#   'PTS': 121,
#   'poss': 100.0},
#  {'TEAM_ABBREVIATION': 'SAS',
#   'GAME_DATE': '2022-11-11T00:00:00',
#   'MATCHUP': 'SAS vs. MIL',
#   'OFF_RATING': 113.3,
#   'DEF_RATING': 95.9,
#   'PTS': 111,
#   'poss': 98.0},
#  {'TEAM_ABBREVIATION': 'ATL',
#   'GAME_DATE': '2022-11-10T00:00:00',
#   'MATCHUP': 'ATL vs. PHI',
#   'OFF_RATING': 98.1,
#   'DEF_RATING': 89.6,
#   'PTS': 104,
#   'poss': 106.0},
#  {'TEAM_ABBREVIATION': 'WAS',
#   'GAME_DATE': '2022-11-10T00:00:00',
#   'MATCHUP': 'WAS vs. DAL',
#   'OFF_RATING': 110.8,
#   'DEF_RATING': 101.9,
#   'PTS': 113,
#   'poss': 102.0},
#  {'TEAM_ABBREVIATION': 'PHI',
#   'GAME_DATE': '2022-11-10T00:00:00',
#   'MATCHUP': 'PHI @ ATL',
#   'OFF_RATING': 89.6,
#   'DEF_RATING': 98.1,
#   'PTS': 95,
#   'poss': 106.0},
#  {'TEAM_ABBREVIATION': 'CHA',
#   'GAME_DATE': '2022-11-10T00:00:00',
#   'MATCHUP': 'CHA @ MIA',
#   'OFF_RATING': 103.7,
#   'DEF_RATING': 110.4,
#   'PTS': 112,
#   'poss': 108.0},
#  {'TEAM_ABBREVIATION': 'DAL',
#   'GAME_DATE': '2022-11-10T00:00:00',
#   'MATCHUP': 'DAL @ WAS',
#   'OFF_RATING': 101.9,
#   'DEF_RATING': 110.8,
#   'PTS': 105,
#   'poss': 103.0},
#  {'TEAM_ABBREVIATION': 'MIA',
#   'GAME_DATE': '2022-11-10T00:00:00',
#   'MATCHUP': 'MIA vs. CHA',
#   'OFF_RATING': 110.4,
#   'DEF_RATING': 103.7,
#   'PTS': 117,
#   'poss': 106.0},
#  {'TEAM_ABBREVIATION': 'HOU',
#   'GAME_DATE': '2022-11-09T00:00:00',
#   'MATCHUP': 'HOU @ TOR',
#   'OFF_RATING': 112.4,
#   'DEF_RATING': 118.4,
#   'PTS': 109,
#   'poss': 97.0},
#  {'TEAM_ABBREVIATION': 'ATL',
#   'GAME_DATE': '2022-11-09T00:00:00',
#   'MATCHUP': 'ATL vs. UTA',
#   'OFF_RATING': 114.4,
#   'DEF_RATING': 119.0,
#   'PTS': 119,
#   'poss': 104.0},
#  {'TEAM_ABBREVIATION': 'CLE',
#   'GAME_DATE': '2022-11-09T00:00:00',
#   'MATCHUP': 'CLE @ SAC',
#   'OFF_RATING': 122.4,
#   'DEF_RATING': 129.6,
#   'PTS': 120,
#   'poss': 98.0},
#  {'TEAM_ABBREVIATION': 'DAL',
#   'GAME_DATE': '2022-11-09T00:00:00',
#   'MATCHUP': 'DAL @ ORL',
#   'OFF_RATING': 92.6,
#   'DEF_RATING': 100.0,
#   'PTS': 87,
#   'poss': 94.0},
#  {'TEAM_ABBREVIATION': 'POR',
#   'GAME_DATE': '2022-11-09T00:00:00',
#   'MATCHUP': 'POR @ CHA',
#   'OFF_RATING': 114.1,
#   'DEF_RATING': 104.4,
#   'PTS': 105,
#   'poss': 92.0},
#  {'TEAM_ABBREVIATION': 'MIL',
#   'GAME_DATE': '2022-11-09T00:00:00',
#   'MATCHUP': 'MIL @ OKC',
#   'OFF_RATING': 115.3,
#   'DEF_RATING': 111.9,
#   'PTS': 136,
#   'poss': 118.0},
#  {'TEAM_ABBREVIATION': 'UTA',
#   'GAME_DATE': '2022-11-09T00:00:00',
#   'MATCHUP': 'UTA @ ATL',
#   'OFF_RATING': 119.0,
#   'DEF_RATING': 114.4,
#   'PTS': 125,
#   'poss': 105.0},
#  {'TEAM_ABBREVIATION': 'CHI',
#   'GAME_DATE': '2022-11-09T00:00:00',
#   'MATCHUP': 'CHI vs. NOP',
#   'OFF_RATING': 108.8,
#   'DEF_RATING': 111.7,
#   'PTS': 111,
#   'poss': 102.0},
#  {'TEAM_ABBREVIATION': 'DET',
#   'GAME_DATE': '2022-11-09T00:00:00',
#   'MATCHUP': 'DET @ BOS',
#   'OFF_RATING': 109.8,
#   'DEF_RATING': 125.5,
#   'PTS': 112,
#   'poss': 102.0},
#  {'TEAM_ABBREVIATION': 'NOP',
#   'GAME_DATE': '2022-11-09T00:00:00',
#   'MATCHUP': 'NOP @ CHI',
#   'OFF_RATING': 111.7,
#   'DEF_RATING': 108.8,
#   'PTS': 115,
#   'poss': 103.0},
#  {'TEAM_ABBREVIATION': 'BOS',
#   'GAME_DATE': '2022-11-09T00:00:00',
#   'MATCHUP': 'BOS vs. DET',
#   'OFF_RATING': 125.5,
#   'DEF_RATING': 109.8,
#   'PTS': 128,
#   'poss': 102.0},
#  {'TEAM_ABBREVIATION': 'IND',
#   'GAME_DATE': '2022-11-09T00:00:00',
#   'MATCHUP': 'IND vs. DEN',
#   'OFF_RATING': 107.2,
#   'DEF_RATING': 111.9,
#   'PTS': 119,
#   'poss': 111.0},
#  {'TEAM_ABBREVIATION': 'SAC',
#   'GAME_DATE': '2022-11-09T00:00:00',
#   'MATCHUP': 'SAC vs. CLE',
#   'OFF_RATING': 129.6,
#   'DEF_RATING': 122.4,
#   'PTS': 127,
#   'poss': 98.0},
#  {'TEAM_ABBREVIATION': 'OKC',
#   'GAME_DATE': '2022-11-09T00:00:00',
#   'MATCHUP': 'OKC vs. MIL',
#   'OFF_RATING': 111.9,
#   'DEF_RATING': 115.3,
#   'PTS': 132,
#   'poss': 118.0},
#  {'TEAM_ABBREVIATION': 'MEM',
#   'GAME_DATE': '2022-11-09T00:00:00',
#   'MATCHUP': 'MEM @ SAS',
#   'OFF_RATING': 119.2,
#   'DEF_RATING': 115.1,
#   'PTS': 124,
#   'poss': 104.0},
#  {'TEAM_ABBREVIATION': 'SAS',
#   'GAME_DATE': '2022-11-09T00:00:00',
#   'MATCHUP': 'SAS vs. MEM',
#   'OFF_RATING': 115.1,
#   'DEF_RATING': 119.2,
#   'PTS': 122,
#   'poss': 106.0},
#  {'TEAM_ABBREVIATION': 'LAL',
#   'GAME_DATE': '2022-11-09T00:00:00',
#   'MATCHUP': 'LAL @ LAC',
#   'OFF_RATING': 100.0,
#   'DEF_RATING': 111.8,
#   'PTS': 101,
#   'poss': 101.0},
#  {'TEAM_ABBREVIATION': 'CHA',
#   'GAME_DATE': '2022-11-09T00:00:00',
#   'MATCHUP': 'CHA vs. POR',
#   'OFF_RATING': 104.4,
#   'DEF_RATING': 114.1,
#   'PTS': 95,
#   'poss': 91.0},
#  {'TEAM_ABBREVIATION': 'BKN',
#   'GAME_DATE': '2022-11-09T00:00:00',
#   'MATCHUP': 'BKN vs. NYK',
#   'OFF_RATING': 112.0,
#   'DEF_RATING': 85.0,
#   'PTS': 112,
#   'poss': 100.0},
#  {'TEAM_ABBREVIATION': 'PHX',
#   'GAME_DATE': '2022-11-09T00:00:00',
#   'MATCHUP': 'PHX @ MIN',
#   'OFF_RATING': 124.0,
#   'DEF_RATING': 113.6,
#   'PTS': 129,
#   'poss': 104.0},
#  {'TEAM_ABBREVIATION': 'TOR',
#   'GAME_DATE': '2022-11-09T00:00:00',
#   'MATCHUP': 'TOR vs. HOU',
#   'OFF_RATING': 118.4,
#   'DEF_RATING': 112.4,
#   'PTS': 116,
#   'poss': 98.0},
#  {'TEAM_ABBREVIATION': 'LAC',
#   'GAME_DATE': '2022-11-09T00:00:00',
#   'MATCHUP': 'LAC vs. LAL',
#   'OFF_RATING': 111.8,
#   'DEF_RATING': 100.0,
#   'PTS': 114,
#   'poss': 102.0},
#  {'TEAM_ABBREVIATION': 'MIN',
#   'GAME_DATE': '2022-11-09T00:00:00',
#   'MATCHUP': 'MIN vs. PHX',
#   'OFF_RATING': 113.6,
#   'DEF_RATING': 124.0,
#   'PTS': 117,
#   'poss': 103.0},
#  {'TEAM_ABBREVIATION': 'DEN',
#   'GAME_DATE': '2022-11-09T00:00:00',
#   'MATCHUP': 'DEN @ IND',
#   'OFF_RATING': 111.9,
#   'DEF_RATING': 107.2,
#   'PTS': 122,
#   'poss': 109.0},
#  {'TEAM_ABBREVIATION': 'ORL',
#   'GAME_DATE': '2022-11-09T00:00:00',
#   'MATCHUP': 'ORL vs. DAL',
#   'OFF_RATING': 100.0,
#   'DEF_RATING': 92.6,
#   'PTS': 94,
#   'poss': 94.0},
#  {'TEAM_ABBREVIATION': 'NYK',
#   'GAME_DATE': '2022-11-09T00:00:00',
#   'MATCHUP': 'NYK @ BKN',
#   'OFF_RATING': 85.0,
#   'DEF_RATING': 112.0,
#   'PTS': 85,
#   'poss': 100.0},
#  {'TEAM_ABBREVIATION': 'NOP',
#   'GAME_DATE': '2022-11-07T00:00:00',
#   'MATCHUP': 'NOP @ IND',
#   'OFF_RATING': 120.8,
#   'DEF_RATING': 126.5,
#   'PTS': 122,
#   'poss': 101.0},
#  {'TEAM_ABBREVIATION': 'HOU',
#   'GAME_DATE': '2022-11-07T00:00:00',
#   'MATCHUP': 'HOU @ ORL',
#   'OFF_RATING': 132.7,
#   'DEF_RATING': 124.5,
#   'PTS': 134,
#   'poss': 101.0},
#  {'TEAM_ABBREVIATION': 'BKN',
#   'GAME_DATE': '2022-11-07T00:00:00',
#   'MATCHUP': 'BKN @ DAL',
#   'OFF_RATING': 105.6,
#   'DEF_RATING': 109.1,
#   'PTS': 94,
#   'poss': 89.0},
#  {'TEAM_ABBREVIATION': 'DEN',
#   'GAME_DATE': '2022-11-07T00:00:00',
#   'MATCHUP': 'DEN @ SAS',
#   'OFF_RATING': 111.7,
#   'DEF_RATING': 105.8,
#   'PTS': 115,
#   'poss': 103.0},
#  {'TEAM_ABBREVIATION': 'MIA',
#   'GAME_DATE': '2022-11-07T00:00:00',
#   'MATCHUP': 'MIA vs. POR',
#   'OFF_RATING': 113.8,
#   'DEF_RATING': 115.8,
#   'PTS': 107,
#   'poss': 94.0},
#  {'TEAM_ABBREVIATION': 'WAS',
#   'GAME_DATE': '2022-11-07T00:00:00',
#   'MATCHUP': 'WAS @ CHA',
#   'OFF_RATING': 111.3,
#   'DEF_RATING': 102.0,
#   'PTS': 108,
#   'poss': 97.0},
#  {'TEAM_ABBREVIATION': 'IND',
#   'GAME_DATE': '2022-11-07T00:00:00',
#   'MATCHUP': 'IND vs. NOP',
#   'OFF_RATING': 126.5,
#   'DEF_RATING': 120.8,
#   'PTS': 129,
#   'poss': 102.0},
#  {'TEAM_ABBREVIATION': 'MEM',
#   'GAME_DATE': '2022-11-07T00:00:00',
#   'MATCHUP': 'MEM vs. BOS',
#   'OFF_RATING': 105.0,
#   'DEF_RATING': 110.1,
#   'PTS': 106,
#   'poss': 101.0},
#  {'TEAM_ABBREVIATION': 'SAS',
#   'GAME_DATE': '2022-11-07T00:00:00',
#   'MATCHUP': 'SAS vs. DEN',
#   'OFF_RATING': 105.8,
#   'DEF_RATING': 111.7,
#   'PTS': 109,
#   'poss': 103.0},
#  {'TEAM_ABBREVIATION': 'SAC',
#   'GAME_DATE': '2022-11-07T00:00:00',
#   'MATCHUP': 'SAC @ GSW',
#   'OFF_RATING': 107.6,
#   'DEF_RATING': 112.6,
#   'PTS': 113,
#   'poss': 105.0},
#  {'TEAM_ABBREVIATION': 'ATL',
#   'GAME_DATE': '2022-11-07T00:00:00',
#   'MATCHUP': 'ATL vs. MIL',
#   'OFF_RATING': 113.6,
#   'DEF_RATING': 96.1,
#   'PTS': 117,
#   'poss': 103.0},
#  {'TEAM_ABBREVIATION': 'BOS',
#   'GAME_DATE': '2022-11-07T00:00:00',
#   'MATCHUP': 'BOS @ MEM',
#   'OFF_RATING': 110.1,
#   'DEF_RATING': 105.0,
#   'PTS': 109,
#   'poss': 99.0},
#  {'TEAM_ABBREVIATION': 'LAC',
#   'GAME_DATE': '2022-11-07T00:00:00',
#   'MATCHUP': 'LAC vs. CLE',
#   'OFF_RATING': 121.4,
#   'DEF_RATING': 118.2,
#   'PTS': 119,
#   'poss': 98.0},
#  {'TEAM_ABBREVIATION': 'TOR',
#   'GAME_DATE': '2022-11-07T00:00:00',
#   'MATCHUP': 'TOR @ CHI',
#   'OFF_RATING': 94.2,
#   'DEF_RATING': 107.8,
#   'PTS': 97,
#   'poss': 103.0},
#  {'TEAM_ABBREVIATION': 'MIL',
#   'GAME_DATE': '2022-11-07T00:00:00',
#   'MATCHUP': 'MIL @ ATL',
#   'OFF_RATING': 96.1,
#   'DEF_RATING': 113.6,
#   'PTS': 98,
#   'poss': 102.0},
#  {'TEAM_ABBREVIATION': 'CHI',
#   'GAME_DATE': '2022-11-07T00:00:00',
#   'MATCHUP': 'CHI vs. TOR',
#   'OFF_RATING': 107.8,
#   'DEF_RATING': 94.2,
#   'PTS': 111,
#   'poss': 103.0},
#  {'TEAM_ABBREVIATION': 'MIN',
#   'GAME_DATE': '2022-11-07T00:00:00',
#   'MATCHUP': 'MIN vs. NYK',
#   'OFF_RATING': 102.9,
#   'DEF_RATING': 115.4,
#   'PTS': 107,
#   'poss': 104.0},
#  {'TEAM_ABBREVIATION': 'UTA',
#   'GAME_DATE': '2022-11-07T00:00:00',
#   'MATCHUP': 'UTA vs. LAL',
#   'OFF_RATING': 133.7,
#   'DEF_RATING': 111.5,
#   'PTS': 139,
#   'poss': 104.0},
#  {'TEAM_ABBREVIATION': 'DAL',
#   'GAME_DATE': '2022-11-07T00:00:00',
#   'MATCHUP': 'DAL vs. BKN',
#   'OFF_RATING': 109.1,
#   'DEF_RATING': 105.6,
#   'PTS': 96,
#   'poss': 88.0},
#  {'TEAM_ABBREVIATION': 'NYK',
#   'GAME_DATE': '2022-11-07T00:00:00',
#   'MATCHUP': 'NYK @ MIN',
#   'OFF_RATING': 115.4,
#   'DEF_RATING': 102.9,
#   'PTS': 120,
#   'poss': 104.0},
#  {'TEAM_ABBREVIATION': 'GSW',
#   'GAME_DATE': '2022-11-07T00:00:00',
#   'MATCHUP': 'GSW vs. SAC',
#   'OFF_RATING': 112.6,
#   'DEF_RATING': 107.6,
#   'PTS': 116,
#   'poss': 103.0},
#  {'TEAM_ABBREVIATION': 'LAL',
#   'GAME_DATE': '2022-11-07T00:00:00',
#   'MATCHUP': 'LAL @ UTA',
#   'OFF_RATING': 111.5,
#   'DEF_RATING': 133.7,
#   'PTS': 116,
#   'poss': 104.0},
#  {'TEAM_ABBREVIATION': 'POR',
#   'GAME_DATE': '2022-11-07T00:00:00',
#   'MATCHUP': 'POR @ MIA',
#   'OFF_RATING': 115.8,
#   'DEF_RATING': 113.8,
#   'PTS': 110,
#   'poss': 95.0},
#  {'TEAM_ABBREVIATION': 'ORL',
#   'GAME_DATE': '2022-11-07T00:00:00',
#   'MATCHUP': 'ORL vs. HOU',
#   'OFF_RATING': 124.5,
#   'DEF_RATING': 132.7,
#   'PTS': 127,
#   'poss': 102.0},
#  {'TEAM_ABBREVIATION': 'CHA',
#   'GAME_DATE': '2022-11-07T00:00:00',
#   'MATCHUP': 'CHA vs. WAS',
#   'OFF_RATING': 102.0,
#   'DEF_RATING': 111.3,
#   'PTS': 100,
#   'poss': 98.0},
#  {'TEAM_ABBREVIATION': 'DET',
#   'GAME_DATE': '2022-11-07T00:00:00',
#   'MATCHUP': 'DET vs. OKC',
#   'OFF_RATING': 109.8,
#   'DEF_RATING': 101.0,
#   'PTS': 112,
#   'poss': 102.0},
#  {'TEAM_ABBREVIATION': 'PHI',
#   'GAME_DATE': '2022-11-07T00:00:00',
#   'MATCHUP': 'PHI vs. PHX',
#   'OFF_RATING': 108.7,
#   'DEF_RATING': 94.6,
#   'PTS': 100,
#   'poss': 92.0},
#  {'TEAM_ABBREVIATION': 'PHX',
#   'GAME_DATE': '2022-11-07T00:00:00',
#   'MATCHUP': 'PHX @ PHI',
#   'OFF_RATING': 94.6,
#   'DEF_RATING': 108.7,
#   'PTS': 88,
#   'poss': 93.0},
#  {'TEAM_ABBREVIATION': 'CLE',
#   'GAME_DATE': '2022-11-07T00:00:00',
#   'MATCHUP': 'CLE @ LAC',
#   'OFF_RATING': 118.2,
#   'DEF_RATING': 121.4,
#   'PTS': 117,
#   'poss': 99.0},
#  {'TEAM_ABBREVIATION': 'OKC',
#   'GAME_DATE': '2022-11-07T00:00:00',
#   'MATCHUP': 'OKC @ DET',
#   'OFF_RATING': 101.0,
#   'DEF_RATING': 109.8,
#   'PTS': 103,
#   'poss': 102.0},
#  {'TEAM_ABBREVIATION': 'WAS',
#   'GAME_DATE': '2022-11-06T00:00:00',
#   'MATCHUP': 'WAS @ MEM',
#   'OFF_RATING': 102.1,
#   'DEF_RATING': 109.6,
#   'PTS': 97,
#   'poss': 95.0},
#  {'TEAM_ABBREVIATION': 'LAC',
#   'GAME_DATE': '2022-11-06T00:00:00',
#   'MATCHUP': 'LAC vs. UTA',
#   'OFF_RATING': 103.0,
#   'DEF_RATING': 111.1,
#   'PTS': 102,
#   'poss': 99.0},
#  {'TEAM_ABBREVIATION': 'CLE',
#   'GAME_DATE': '2022-11-06T00:00:00',
#   'MATCHUP': 'CLE @ LAL',
#   'OFF_RATING': 112.9,
#   'DEF_RATING': 99.0,
#   'PTS': 114,
#   'poss': 101.0},
#  {'TEAM_ABBREVIATION': 'CHI',
#   'GAME_DATE': '2022-11-06T00:00:00',
#   'MATCHUP': 'CHI @ TOR',
#   'OFF_RATING': 108.3,
#   'DEF_RATING': 118.9,
#   'PTS': 104,
#   'poss': 96.0},
#  {'TEAM_ABBREVIATION': 'TOR',
#   'GAME_DATE': '2022-11-06T00:00:00',
#   'MATCHUP': 'TOR vs. CHI',
#   'OFF_RATING': 118.9,
#   'DEF_RATING': 108.3,
#   'PTS': 113,
#   'poss': 95.0},
#  {'TEAM_ABBREVIATION': 'LAL',
#   'GAME_DATE': '2022-11-06T00:00:00',
#   'MATCHUP': 'LAL vs. CLE',
#   'OFF_RATING': 99.0,
#   'DEF_RATING': 112.9,
#   'PTS': 100,
#   'poss': 101.0},
#  {'TEAM_ABBREVIATION': 'UTA',
#   'GAME_DATE': '2022-11-06T00:00:00',
#   'MATCHUP': 'UTA @ LAC',
#   'OFF_RATING': 111.1,
#   'DEF_RATING': 103.0,
#   'PTS': 110,
#   'poss': 99.0},
#  {'TEAM_ABBREVIATION': 'MEM',
#   'GAME_DATE': '2022-11-06T00:00:00',
#   'MATCHUP': 'MEM vs. WAS',
#   'OFF_RATING': 109.6,
#   'DEF_RATING': 102.1,
#   'PTS': 103,
#   'poss': 94.0},
#  {'TEAM_ABBREVIATION': 'DEN',
#   'GAME_DATE': '2022-11-05T00:00:00',
#   'MATCHUP': 'DEN vs. SAS',
#   'OFF_RATING': 128.6,
#   'DEF_RATING': 103.1,
#   'PTS': 126,
#   'poss': 98.0},
#  {'TEAM_ABBREVIATION': 'BKN',
#   'GAME_DATE': '2022-11-05T00:00:00',
#   'MATCHUP': 'BKN @ CHA',
#   'OFF_RATING': 105.4,
#   'DEF_RATING': 100.0,
#   'PTS': 98,
#   'poss': 93.0},
#  {'TEAM_ABBREVIATION': 'NOP',
#   'GAME_DATE': '2022-11-05T00:00:00',
#   'MATCHUP': 'NOP @ ATL',
#   'OFF_RATING': 107.1,
#   'DEF_RATING': 108.8,
#   'PTS': 121,
#   'poss': 113.0},
#  {'TEAM_ABBREVIATION': 'POR',
#   'GAME_DATE': '2022-11-05T00:00:00',
#   'MATCHUP': 'POR @ PHX',
#   'OFF_RATING': 87.2,
#   'DEF_RATING': 106.3,
#   'PTS': 82,
#   'poss': 94.0},
#  {'TEAM_ABBREVIATION': 'PHX',
#   'GAME_DATE': '2022-11-05T00:00:00',
#   'MATCHUP': 'PHX vs. POR',
#   'OFF_RATING': 106.3,
#   'DEF_RATING': 87.2,
#   'PTS': 102,
#   'poss': 96.0},
#  {'TEAM_ABBREVIATION': 'ORL',
#   'GAME_DATE': '2022-11-05T00:00:00',
#   'MATCHUP': 'ORL vs. SAC',
#   'OFF_RATING': 111.8,
#   'DEF_RATING': 113.5,
#   'PTS': 123,
#   'poss': 110.0},
#  {'TEAM_ABBREVIATION': 'SAS',
#   'GAME_DATE': '2022-11-05T00:00:00',
#   'MATCHUP': 'SAS @ DEN',
#   'OFF_RATING': 103.1,
#   'DEF_RATING': 128.6,
#   'PTS': 101,
#   'poss': 98.0},
#  {'TEAM_ABBREVIATION': 'NYK',
#   'GAME_DATE': '2022-11-05T00:00:00',
#   'MATCHUP': 'NYK vs. BOS',
#   'OFF_RATING': 119.2,
#   'DEF_RATING': 135.7,
#   'PTS': 118,
#   'poss': 99.0},
#  {'TEAM_ABBREVIATION': 'BOS',
#   'GAME_DATE': '2022-11-05T00:00:00',
#   'MATCHUP': 'BOS @ NYK',
#   'OFF_RATING': 135.7,
#   'DEF_RATING': 119.2,
#   'PTS': 133,
#   'poss': 98.0},
#  {'TEAM_ABBREVIATION': 'OKC',
#   'GAME_DATE': '2022-11-05T00:00:00',
#   'MATCHUP': 'OKC @ MIL',
#   'OFF_RATING': 96.9,
#   'DEF_RATING': 111.3,
#   'PTS': 94,
#   'poss': 97.0},
#  {'TEAM_ABBREVIATION': 'MIL',
#   'GAME_DATE': '2022-11-05T00:00:00',
#   'MATCHUP': 'MIL vs. OKC',
#   'OFF_RATING': 111.3,
#   'DEF_RATING': 96.9,
#   'PTS': 108,
#   'poss': 97.0},
#  {'TEAM_ABBREVIATION': 'CHA',
#   'GAME_DATE': '2022-11-05T00:00:00',
#   'MATCHUP': 'CHA vs. BKN',
#   'OFF_RATING': 100.0,
#   'DEF_RATING': 105.4,
#   'PTS': 94,
#   'poss': 94.0},
#  {'TEAM_ABBREVIATION': 'SAC',
#   'GAME_DATE': '2022-11-05T00:00:00',
#   'MATCHUP': 'SAC @ ORL',
#   'OFF_RATING': 113.5,
#   'DEF_RATING': 111.8,
#   'PTS': 126,
#   'poss': 111.0},
#  {'TEAM_ABBREVIATION': 'HOU',
#   'GAME_DATE': '2022-11-05T00:00:00',
#   'MATCHUP': 'HOU @ MIN',
#   'OFF_RATING': 113.6,
#   'DEF_RATING': 125.2,
#   'PTS': 117,
#   'poss': 103.0},
#  {'TEAM_ABBREVIATION': 'MIN',
#   'GAME_DATE': '2022-11-05T00:00:00',
#   'MATCHUP': 'MIN vs. HOU',
#   'OFF_RATING': 125.2,
#   'DEF_RATING': 113.6,
#   'PTS': 129,
#   'poss': 103.0},
#  {'TEAM_ABBREVIATION': 'ATL',
#   'GAME_DATE': '2022-11-05T00:00:00',
#   'MATCHUP': 'ATL vs. NOP',
#   'OFF_RATING': 108.8,
#   'DEF_RATING': 107.1,
#   'PTS': 124,
#   'poss': 114.0},
#  {'TEAM_ABBREVIATION': 'POR',
#   'GAME_DATE': '2022-11-04T00:00:00',
#   'MATCHUP': 'POR @ PHX',
#   'OFF_RATING': 112.5,
#   'DEF_RATING': 112.8,
#   'PTS': 108,
#   'poss': 96.0},
#  {'TEAM_ABBREVIATION': 'NYK',
#   'GAME_DATE': '2022-11-04T00:00:00',
#   'MATCHUP': 'NYK @ PHI',
#   'OFF_RATING': 101.0,
#   'DEF_RATING': 101.0,
#   'PTS': 106,
#   'poss': 105.0},
#  {'TEAM_ABBREVIATION': 'IND',
#   'GAME_DATE': '2022-11-04T00:00:00',
#   'MATCHUP': 'IND vs. MIA',
#   'OFF_RATING': 100.0,
#   'DEF_RATING': 96.1,
#   'PTS': 101,
#   'poss': 101.0},
#  {'TEAM_ABBREVIATION': 'PHX',
#   'GAME_DATE': '2022-11-04T00:00:00',
#   'MATCHUP': 'PHX vs. POR',
#   'OFF_RATING': 112.8,
#   'DEF_RATING': 112.5,
#   'PTS': 106,
#   'poss': 94.0},
#  {'TEAM_ABBREVIATION': 'DAL',
#   'GAME_DATE': '2022-11-04T00:00:00',
#   'MATCHUP': 'DAL vs. TOR',
#   'OFF_RATING': 114.4,
#   'DEF_RATING': 114.6,
#   'PTS': 111,
#   'poss': 97.0},
#  {'TEAM_ABBREVIATION': 'TOR',
#   'GAME_DATE': '2022-11-04T00:00:00',
#   'MATCHUP': 'TOR @ DAL',
#   'OFF_RATING': 114.6,
#   'DEF_RATING': 114.4,
#   'PTS': 110,
#   'poss': 96.0},
#  {'TEAM_ABBREVIATION': 'BOS',
#   'GAME_DATE': '2022-11-04T00:00:00',
#   'MATCHUP': 'BOS vs. CHI',
#   'OFF_RATING': 119.4,
#   'DEF_RATING': 114.4,
#   'PTS': 123,
#   'poss': 103.0},
#  {'TEAM_ABBREVIATION': 'MIA',
#   'GAME_DATE': '2022-11-04T00:00:00',
#   'MATCHUP': 'MIA @ IND',
#   'OFF_RATING': 96.1,
#   'DEF_RATING': 100.0,
#   'PTS': 99,
#   'poss': 103.0},
#  {'TEAM_ABBREVIATION': 'MIL',
#   'GAME_DATE': '2022-11-04T00:00:00',
#   'MATCHUP': 'MIL @ MIN',
#   'OFF_RATING': 109.5,
#   'DEF_RATING': 99.0,
#   'PTS': 115,
#   'poss': 105.0},
#  {'TEAM_ABBREVIATION': 'UTA',
#   'GAME_DATE': '2022-11-04T00:00:00',
#   'MATCHUP': 'UTA @ LAL',
#   'OFF_RATING': 134.0,
#   'DEF_RATING': 120.8,
#   'PTS': 130,
#   'poss': 97.0},
#  {'TEAM_ABBREVIATION': 'MIN',
#   'GAME_DATE': '2022-11-04T00:00:00',
#   'MATCHUP': 'MIN vs. MIL',
#   'OFF_RATING': 99.0,
#   'DEF_RATING': 109.5,
#   'PTS': 102,
#   'poss': 103.0},
#  {'TEAM_ABBREVIATION': 'LAL',
#   'GAME_DATE': '2022-11-04T00:00:00',
#   'MATCHUP': 'LAL vs. UTA',
#   'OFF_RATING': 120.8,
#   'DEF_RATING': 134.0,
#   'PTS': 116,
#   'poss': 96.0},
#  {'TEAM_ABBREVIATION': 'DET',
#   'GAME_DATE': '2022-11-04T00:00:00',
#   'MATCHUP': 'DET vs. CLE',
#   'OFF_RATING': 91.7,
#   'DEF_RATING': 116.7,
#   'PTS': 88,
#   'poss': 96.0},
#  {'TEAM_ABBREVIATION': 'CLE',
#   'GAME_DATE': '2022-11-04T00:00:00',
#   'MATCHUP': 'CLE @ DET',
#   'OFF_RATING': 116.7,
#   'DEF_RATING': 91.7,
#   'PTS': 112,
#   'poss': 96.0},
#  {'TEAM_ABBREVIATION': 'GSW',
#   'GAME_DATE': '2022-11-04T00:00:00',
#   'MATCHUP': 'GSW @ NOP',
#   'OFF_RATING': 106.1,
#   'DEF_RATING': 115.2,
#   'PTS': 105,
#   'poss': 99.0},
#  {'TEAM_ABBREVIATION': 'NOP',
#   'GAME_DATE': '2022-11-04T00:00:00',
#   'MATCHUP': 'NOP vs. GSW',
#   'OFF_RATING': 115.2,
#   'DEF_RATING': 106.1,
#   'PTS': 114,
#   'poss': 99.0},
#  {'TEAM_ABBREVIATION': 'SAS',
#   'GAME_DATE': '2022-11-04T00:00:00',
#   'MATCHUP': 'SAS vs. LAC',
#   'OFF_RATING': 106.0,
#   'DEF_RATING': 111.9,
#   'PTS': 106,
#   'poss': 100.0},
#  {'TEAM_ABBREVIATION': 'CHA',
#   'GAME_DATE': '2022-11-04T00:00:00',
#   'MATCHUP': 'CHA @ MEM',
#   'OFF_RATING': 91.7,
#   'DEF_RATING': 121.5,
#   'PTS': 99,
#   'poss': 108.0},
#  {'TEAM_ABBREVIATION': 'LAC',
#   'GAME_DATE': '2022-11-04T00:00:00',
#   'MATCHUP': 'LAC @ SAS',
#   'OFF_RATING': 111.9,
#   'DEF_RATING': 106.0,
#   'PTS': 113,
#   'poss': 101.0},
#  {'TEAM_ABBREVIATION': 'CHI',
#   'GAME_DATE': '2022-11-04T00:00:00',
#   'MATCHUP': 'CHI @ BOS',
#   'OFF_RATING': 114.4,
#   'DEF_RATING': 119.4,
#   'PTS': 119,
#   'poss': 104.0},
#  {'TEAM_ABBREVIATION': 'MEM',
#   'GAME_DATE': '2022-11-04T00:00:00',
#   'MATCHUP': 'MEM vs. CHA',
#   'OFF_RATING': 121.5,
#   'DEF_RATING': 91.7,
#   'PTS': 130,
#   'poss': 107.0},
#  {'TEAM_ABBREVIATION': 'WAS',
#   'GAME_DATE': '2022-11-04T00:00:00',
#   'MATCHUP': 'WAS vs. BKN',
#   'OFF_RATING': 87.8,
#   'DEF_RATING': 132.0,
#   'PTS': 86,
#   'poss': 98.0},
#  {'TEAM_ABBREVIATION': 'BKN',
#   'GAME_DATE': '2022-11-04T00:00:00',
#   'MATCHUP': 'BKN @ WAS',
#   'OFF_RATING': 132.0,
#   'DEF_RATING': 87.8,
#   'PTS': 128,
#   'poss': 97.0},
#  {'TEAM_ABBREVIATION': 'PHI',
#   'GAME_DATE': '2022-11-04T00:00:00',
#   'MATCHUP': 'PHI vs. NYK',
#   'OFF_RATING': 101.0,
#   'DEF_RATING': 101.0,
#   'PTS': 104,
#   'poss': 103.0},
#  {'TEAM_ABBREVIATION': 'ORL',
#   'GAME_DATE': '2022-11-03T00:00:00',
#   'MATCHUP': 'ORL vs. GSW',
#   'OFF_RATING': 126.2,
#   'DEF_RATING': 122.9,
#   'PTS': 130,
#   'poss': 103.0},
#  {'TEAM_ABBREVIATION': 'GSW',
#   'GAME_DATE': '2022-11-03T00:00:00',
#   'MATCHUP': 'GSW @ ORL',
#   'OFF_RATING': 122.9,
#   'DEF_RATING': 126.2,
#   'PTS': 129,
#   'poss': 105.0},
#  {'TEAM_ABBREVIATION': 'DEN',
#   'GAME_DATE': '2022-11-03T00:00:00',
#   'MATCHUP': 'DEN @ OKC',
#   'OFF_RATING': 119.6,
#   'DEF_RATING': 106.8,
#   'PTS': 122,
#   'poss': 102.0},
#  {'TEAM_ABBREVIATION': 'OKC',
#   'GAME_DATE': '2022-11-03T00:00:00',
#   'MATCHUP': 'OKC vs. DEN',
#   'OFF_RATING': 106.8,
#   'DEF_RATING': 119.6,
#   'PTS': 110,
#   'poss': 103.0},
#  {'TEAM_ABBREVIATION': 'NYK',
#   'GAME_DATE': '2022-11-02T00:00:00',
#   'MATCHUP': 'NYK vs. ATL',
#   'OFF_RATING': 98.0,
#   'DEF_RATING': 110.9,
#   'PTS': 99,
#   'poss': 101.0},
#  {'TEAM_ABBREVIATION': 'CHA',
#   'GAME_DATE': '2022-11-02T00:00:00',
#   'MATCHUP': 'CHA @ CHI',
#   'OFF_RATING': 85.4,
#   'DEF_RATING': 105.0,
#   'PTS': 88,
#   'poss': 103.0},
#  {'TEAM_ABBREVIATION': 'BOS',
#   'GAME_DATE': '2022-11-02T00:00:00',
#   'MATCHUP': 'BOS @ CLE',
#   'OFF_RATING': 102.7,
#   'DEF_RATING': 103.6,
#   'PTS': 113,
#   'poss': 110.0},
#  {'TEAM_ABBREVIATION': 'PHI',
#   'GAME_DATE': '2022-11-02T00:00:00',
#   'MATCHUP': 'PHI vs. WAS',
#   'OFF_RATING': 118.1,
#   'DEF_RATING': 128.7,
#   'PTS': 111,
#   'poss': 94.0},
#  {'TEAM_ABBREVIATION': 'CLE',
#   'GAME_DATE': '2022-11-02T00:00:00',
#   'MATCHUP': 'CLE vs. BOS',
#   'OFF_RATING': 103.6,
#   'DEF_RATING': 102.7,
#   'PTS': 114,
#   'poss': 110.0},
#  {'TEAM_ABBREVIATION': 'HOU',
#   'GAME_DATE': '2022-11-02T00:00:00',
#   'MATCHUP': 'HOU vs. LAC',
#   'OFF_RATING': 102.0,
#   'DEF_RATING': 111.2,
#   'PTS': 101,
#   'poss': 99.0},
#  {'TEAM_ABBREVIATION': 'DET',
#   'GAME_DATE': '2022-11-02T00:00:00',
#   'MATCHUP': 'DET @ MIL',
#   'OFF_RATING': 87.5,
#   'DEF_RATING': 112.6,
#   'PTS': 91,
#   'poss': 104.0},
#  {'TEAM_ABBREVIATION': 'POR',
#   'GAME_DATE': '2022-11-02T00:00:00',
#   'MATCHUP': 'POR vs. MEM',
#   'OFF_RATING': 106.0,
#   'DEF_RATING': 108.8,
#   'PTS': 106,
#   'poss': 100.0},
#  {'TEAM_ABBREVIATION': 'UTA',
#   'GAME_DATE': '2022-11-02T00:00:00',
#   'MATCHUP': 'UTA @ DAL',
#   'OFF_RATING': 108.7,
#   'DEF_RATING': 110.8,
#   'PTS': 100,
#   'poss': 92.0},
#  {'TEAM_ABBREVIATION': 'SAC',
#   'GAME_DATE': '2022-11-02T00:00:00',
#   'MATCHUP': 'SAC @ MIA',
#   'OFF_RATING': 111.5,
#   'DEF_RATING': 113.4,
#   'PTS': 107,
#   'poss': 96.0},
#  {'TEAM_ABBREVIATION': 'NOP',
#   'GAME_DATE': '2022-11-02T00:00:00',
#   'MATCHUP': 'NOP @ LAL',
#   'OFF_RATING': 101.7,
#   'DEF_RATING': 103.4,
#   'PTS': 117,
#   'poss': 115.0},
#  {'TEAM_ABBREVIATION': 'SAS',
#   'GAME_DATE': '2022-11-02T00:00:00',
#   'MATCHUP': 'SAS vs. TOR',
#   'OFF_RATING': 90.9,
#   'DEF_RATING': 128.8,
#   'PTS': 100,
#   'poss': 110.0},
#  {'TEAM_ABBREVIATION': 'ATL',
#   'GAME_DATE': '2022-11-02T00:00:00',
#   'MATCHUP': 'ATL @ NYK',
#   'OFF_RATING': 110.9,
#   'DEF_RATING': 98.0,
#   'PTS': 112,
#   'poss': 101.0},
#  {'TEAM_ABBREVIATION': 'CHI',
#   'GAME_DATE': '2022-11-02T00:00:00',
#   'MATCHUP': 'CHI vs. CHA',
#   'OFF_RATING': 105.0,
#   'DEF_RATING': 85.4,
#   'PTS': 106,
#   'poss': 101.0},
#  {'TEAM_ABBREVIATION': 'MEM',
#   'GAME_DATE': '2022-11-02T00:00:00',
#   'MATCHUP': 'MEM @ POR',
#   'OFF_RATING': 108.8,
#   'DEF_RATING': 106.0,
#   'PTS': 111,
#   'poss': 102.0},
#  {'TEAM_ABBREVIATION': 'WAS',
#   'GAME_DATE': '2022-11-02T00:00:00',
#   'MATCHUP': 'WAS @ PHI',
#   'OFF_RATING': 128.7,
#   'DEF_RATING': 118.1,
#   'PTS': 121,
#   'poss': 94.0},
#  {'TEAM_ABBREVIATION': 'LAC',
#   'GAME_DATE': '2022-11-02T00:00:00',
#   'MATCHUP': 'LAC @ HOU',
#   'OFF_RATING': 111.2,
#   'DEF_RATING': 102.0,
#   'PTS': 109,
#   'poss': 98.0},
#  {'TEAM_ABBREVIATION': 'DAL',
#   'GAME_DATE': '2022-11-02T00:00:00',
#   'MATCHUP': 'DAL vs. UTA',
#   'OFF_RATING': 110.8,
#   'DEF_RATING': 108.7,
#   'PTS': 103,
#   'poss': 93.0},
#  {'TEAM_ABBREVIATION': 'MIA',
#   'GAME_DATE': '2022-11-02T00:00:00',
#   'MATCHUP': 'MIA vs. SAC',
#   'OFF_RATING': 113.4,
#   'DEF_RATING': 111.5,
#   'PTS': 110,
#   'poss': 97.0},
#  {'TEAM_ABBREVIATION': 'LAL',
#   'GAME_DATE': '2022-11-02T00:00:00',
#   'MATCHUP': 'LAL vs. NOP',
#   'OFF_RATING': 103.4,
#   'DEF_RATING': 101.7,
#   'PTS': 120,
#   'poss': 116.0},
#  {'TEAM_ABBREVIATION': 'MIL',
#   'GAME_DATE': '2022-11-02T00:00:00',
#   'MATCHUP': 'MIL vs. DET',
#   'OFF_RATING': 112.6,
#   'DEF_RATING': 87.5,
#   'PTS': 116,
#   'poss': 103.0},
#  {'TEAM_ABBREVIATION': 'TOR',
#   'GAME_DATE': '2022-11-02T00:00:00',
#   'MATCHUP': 'TOR @ SAS',
#   'OFF_RATING': 128.8,
#   'DEF_RATING': 90.9,
#   'PTS': 143,
#   'poss': 111.0},
#  {'TEAM_ABBREVIATION': 'GSW',
#   'GAME_DATE': '2022-11-01T00:00:00',
#   'MATCHUP': 'GSW @ MIA',
#   'OFF_RATING': 112.4,
#   'DEF_RATING': 118.4,
#   'PTS': 109,
#   'poss': 97.0},
#  {'TEAM_ABBREVIATION': 'MIA',
#   'GAME_DATE': '2022-11-01T00:00:00',
#   'MATCHUP': 'MIA vs. GSW',
#   'OFF_RATING': 118.4,
#   'DEF_RATING': 112.4,
#   'PTS': 116,
#   'poss': 98.0},
#  {'TEAM_ABBREVIATION': 'BKN',
#   'GAME_DATE': '2022-11-01T00:00:00',
#   'MATCHUP': 'BKN vs. CHI',
#   'OFF_RATING': 104.2,
#   'DEF_RATING': 112.5,
#   'PTS': 99,
#   'poss': 95.0},
#  {'TEAM_ABBREVIATION': 'PHX',
#   'GAME_DATE': '2022-11-01T00:00:00',
#   'MATCHUP': 'PHX vs. MIN',
#   'OFF_RATING': 117.2,
#   'DEF_RATING': 108.1,
#   'PTS': 116,
#   'poss': 99.0},
#  {'TEAM_ABBREVIATION': 'ORL',
#   'GAME_DATE': '2022-11-01T00:00:00',
#   'MATCHUP': 'ORL @ OKC',
#   'OFF_RATING': 100.0,
#   'DEF_RATING': 108.4,
#   'PTS': 108,
#   'poss': 108.0},
#  {'TEAM_ABBREVIATION': 'CHI',
#   'GAME_DATE': '2022-11-01T00:00:00',
#   'MATCHUP': 'CHI @ BKN',
#   'OFF_RATING': 112.5,
#   'DEF_RATING': 104.2,
#   'PTS': 108,
#   'poss': 96.0},
#  {'TEAM_ABBREVIATION': 'OKC',
#   'GAME_DATE': '2022-11-01T00:00:00',
#   'MATCHUP': 'OKC vs. ORL',
#   'OFF_RATING': 108.4,
#   'DEF_RATING': 100.0,
#   'PTS': 116,
#   'poss': 107.0},
#  {'TEAM_ABBREVIATION': 'MIN',
#   'GAME_DATE': '2022-11-01T00:00:00',
#   'MATCHUP': 'MIN @ PHX',
#   'OFF_RATING': 108.1,
#   'DEF_RATING': 117.2,
#   'PTS': 107,
#   'poss': 99.0},
#  {'TEAM_ABBREVIATION': 'HOU',
#   'GAME_DATE': '2022-10-31T00:00:00',
#   'MATCHUP': 'HOU @ LAC',
#   'OFF_RATING': 93.0,
#   'DEF_RATING': 96.0,
#   'PTS': 93,
#   'poss': 100.0},
#  {'TEAM_ABBREVIATION': 'ATL',
#   'GAME_DATE': '2022-10-31T00:00:00',
#   'MATCHUP': 'ATL @ TOR',
#   'OFF_RATING': 105.8,
#   'DEF_RATING': 135.0,
#   'PTS': 109,
#   'poss': 103.0},
#  {'TEAM_ABBREVIATION': 'TOR',
#   'GAME_DATE': '2022-10-31T00:00:00',
#   'MATCHUP': 'TOR vs. ATL',
#   'OFF_RATING': 135.0,
#   'DEF_RATING': 105.8,
#   'PTS': 139,
#   'poss': 103.0},
#  {'TEAM_ABBREVIATION': 'SAC',
#   'GAME_DATE': '2022-10-31T00:00:00',
#   'MATCHUP': 'SAC @ CHA',
#   'OFF_RATING': 111.7,
#   'DEF_RATING': 105.9,
#   'PTS': 115,
#   'poss': 103.0},
#  {'TEAM_ABBREVIATION': 'MIL',
#   'GAME_DATE': '2022-10-31T00:00:00',
#   'MATCHUP': 'MIL vs. DET',
#   'OFF_RATING': 111.1,
#   'DEF_RATING': 109.1,
#   'PTS': 110,
#   'poss': 99.0},
#  {'TEAM_ABBREVIATION': 'MEM',
#   'GAME_DATE': '2022-10-31T00:00:00',
#   'MATCHUP': 'MEM @ UTA',
#   'OFF_RATING': 100.0,
#   'DEF_RATING': 117.5,
#   'PTS': 105,
#   'poss': 105.0},
#  {'TEAM_ABBREVIATION': 'BKN',
#   'GAME_DATE': '2022-10-31T00:00:00',
#   'MATCHUP': 'BKN vs. IND',
#   'OFF_RATING': 110.5,
#   'DEF_RATING': 104.8,
#   'PTS': 116,
#   'poss': 105.0},
#  {'TEAM_ABBREVIATION': 'PHI',
#   'GAME_DATE': '2022-10-31T00:00:00',
#   'MATCHUP': 'PHI @ WAS',
#   'OFF_RATING': 119.2,
#   'DEF_RATING': 112.1,
#   'PTS': 118,
#   'poss': 99.0},
#  {'TEAM_ABBREVIATION': 'UTA',
#   'GAME_DATE': '2022-10-31T00:00:00',
#   'MATCHUP': 'UTA vs. MEM',
#   'OFF_RATING': 117.5,
#   'DEF_RATING': 100.0,
#   'PTS': 121,
#   'poss': 103.0},
#  {'TEAM_ABBREVIATION': 'CHA',
#   'GAME_DATE': '2022-10-31T00:00:00',
#   'MATCHUP': 'CHA vs. SAC',
#   'OFF_RATING': 105.9,
#   'DEF_RATING': 111.7,
#   'PTS': 108,
#   'poss': 102.0},
#  {'TEAM_ABBREVIATION': 'WAS',
#   'GAME_DATE': '2022-10-31T00:00:00',
#   'MATCHUP': 'WAS vs. PHI',
#   'OFF_RATING': 112.1,
#   'DEF_RATING': 119.2,
#   'PTS': 111,
#   'poss': 99.0},
#  {'TEAM_ABBREVIATION': 'LAC',
#   'GAME_DATE': '2022-10-31T00:00:00',
#   'MATCHUP': 'LAC vs. HOU',
#   'OFF_RATING': 96.0,
#   'DEF_RATING': 93.0,
#   'PTS': 95,
#   'poss': 99.0},
#  {'TEAM_ABBREVIATION': 'IND',
#   'GAME_DATE': '2022-10-31T00:00:00',
#   'MATCHUP': 'IND @ BKN',
#   'OFF_RATING': 104.8,
#   'DEF_RATING': 110.5,
#   'PTS': 109,
#   'poss': 104.0},
#  {'TEAM_ABBREVIATION': 'DET',
#   'GAME_DATE': '2022-10-31T00:00:00',
#   'MATCHUP': 'DET @ MIL',
#   'OFF_RATING': 109.1,
#   'DEF_RATING': 111.1,
#   'PTS': 108,
#   'poss': 99.0},
#  {'TEAM_ABBREVIATION': 'DEN',
#   'GAME_DATE': '2022-10-30T00:00:00',
#   'MATCHUP': 'DEN @ LAL',
#   'OFF_RATING': 110.0,
#   'DEF_RATING': 122.2,
#   'PTS': 110,
#   'poss': 100.0},
#  {'TEAM_ABBREVIATION': 'HOU',
#   'GAME_DATE': '2022-10-30T00:00:00',
#   'MATCHUP': 'HOU @ PHX',
#   'OFF_RATING': 111.2,
#   'DEF_RATING': 126.5,
#   'PTS': 109,
#   'poss': 98.0},
#  {'TEAM_ABBREVIATION': 'CLE',
#   'GAME_DATE': '2022-10-30T00:00:00',
#   'MATCHUP': 'CLE vs. NYK',
#   'OFF_RATING': 122.2,
#   'DEF_RATING': 110.2,
#   'PTS': 121,
#   'poss': 99.0},
#  {'TEAM_ABBREVIATION': 'DAL',
#   'GAME_DATE': '2022-10-30T00:00:00',
#   'MATCHUP': 'DAL vs. ORL',
#   'OFF_RATING': 125.3,
#   'DEF_RATING': 114.1,
#   'PTS': 114,
#   'poss': 91.0},
#  {'TEAM_ABBREVIATION': 'DET',
#   'GAME_DATE': '2022-10-30T00:00:00',
#   'MATCHUP': 'DET vs. GSW',
#   'OFF_RATING': 125.5,
#   'DEF_RATING': 109.6,
#   'PTS': 128,
#   'poss': 102.0},
#  {'TEAM_ABBREVIATION': 'BOS',
#   'GAME_DATE': '2022-10-30T00:00:00',
#   'MATCHUP': 'BOS vs. WAS',
#   'OFF_RATING': 115.5,
#   'DEF_RATING': 96.9,
#   'PTS': 112,
#   'poss': 97.0},
#  {'TEAM_ABBREVIATION': 'SAS',
#   'GAME_DATE': '2022-10-30T00:00:00',
#   'MATCHUP': 'SAS vs. MIN',
#   'OFF_RATING': 108.1,
#   'DEF_RATING': 99.0,
#   'PTS': 107,
#   'poss': 99.0},
#  {'TEAM_ABBREVIATION': 'MIN',
#   'GAME_DATE': '2022-10-30T00:00:00',
#   'MATCHUP': 'MIN @ SAS',
#   'OFF_RATING': 99.0,
#   'DEF_RATING': 108.1,
#   'PTS': 98,
#   'poss': 99.0},
#  {'TEAM_ABBREVIATION': 'LAC',
#   'GAME_DATE': '2022-10-30T00:00:00',
#   'MATCHUP': 'LAC vs. NOP',
#   'OFF_RATING': 96.8,
#   'DEF_RATING': 117.9,
#   'PTS': 91,
#   'poss': 94.0},
#  {'TEAM_ABBREVIATION': 'LAL',
#   'GAME_DATE': '2022-10-30T00:00:00',
#   'MATCHUP': 'LAL vs. DEN',
#   'OFF_RATING': 122.2,
#   'DEF_RATING': 110.0,
#   'PTS': 121,
#   'poss': 99.0},
#  {'TEAM_ABBREVIATION': 'GSW',
#   'GAME_DATE': '2022-10-30T00:00:00',
#   'MATCHUP': 'GSW @ DET',
#   'OFF_RATING': 109.6,
#   'DEF_RATING': 125.5,
#   'PTS': 114,
#   'poss': 104.0},
#  {'TEAM_ABBREVIATION': 'PHX',
#   'GAME_DATE': '2022-10-30T00:00:00',
#   'MATCHUP': 'PHX vs. HOU',
#   'OFF_RATING': 126.5,
#   'DEF_RATING': 111.2,
#   'PTS': 124,
#   'poss': 98.0},
#  {'TEAM_ABBREVIATION': 'NYK',
#   'GAME_DATE': '2022-10-30T00:00:00',
#   'MATCHUP': 'NYK @ CLE',
#   'OFF_RATING': 110.2,
#   'DEF_RATING': 122.2,
#   'PTS': 108,
#   'poss': 98.0},
#  {'TEAM_ABBREVIATION': 'WAS',
#   'GAME_DATE': '2022-10-30T00:00:00',
#   'MATCHUP': 'WAS @ BOS',
#   'OFF_RATING': 96.9,
#   'DEF_RATING': 115.5,
#   'PTS': 94,
#   'poss': 97.0},
#  {'TEAM_ABBREVIATION': 'ORL',
#   'GAME_DATE': '2022-10-30T00:00:00',
#   'MATCHUP': 'ORL @ DAL',
#   'OFF_RATING': 114.1,
#   'DEF_RATING': 125.3,
#   'PTS': 105,
#   'poss': 92.0},
#  {'TEAM_ABBREVIATION': 'NOP',
#   'GAME_DATE': '2022-10-30T00:00:00',
#   'MATCHUP': 'NOP @ LAC',
#   'OFF_RATING': 117.9,
#   'DEF_RATING': 96.8,
#   'PTS': 112,
#   'poss': 95.0},
#  {'TEAM_ABBREVIATION': 'CHI',
#   'GAME_DATE': '2022-10-29T00:00:00',
#   'MATCHUP': 'CHI vs. PHI',
#   'OFF_RATING': 106.9,
#   'DEF_RATING': 112.9,
#   'PTS': 109,
#   'poss': 102.0},
#  {'TEAM_ABBREVIATION': 'DAL',
#   'GAME_DATE': '2022-10-29T00:00:00',
#   'MATCHUP': 'DAL vs. OKC',
#   'OFF_RATING': 101.8,
#   'DEF_RATING': 109.3,
#   'PTS': 111,
#   'poss': 109.0},
#  {'TEAM_ABBREVIATION': 'IND',
#   'GAME_DATE': '2022-10-29T00:00:00',
#   'MATCHUP': 'IND @ BKN',
#   'OFF_RATING': 128.9,
#   'DEF_RATING': 120.8,
#   'PTS': 125,
#   'poss': 97.0},
#  {'TEAM_ABBREVIATION': 'MIL',
#   'GAME_DATE': '2022-10-29T00:00:00',
#   'MATCHUP': 'MIL vs. ATL',
#   'OFF_RATING': 121.8,
#   'DEF_RATING': 113.9,
#   'PTS': 123,
#   'poss': 101.0},
#  {'TEAM_ABBREVIATION': 'MIA',
#   'GAME_DATE': '2022-10-29T00:00:00',
#   'MATCHUP': 'MIA @ SAC',
#   'OFF_RATING': 110.8,
#   'DEF_RATING': 119.0,
#   'PTS': 113,
#   'poss': 102.0},
#  {'TEAM_ABBREVIATION': 'CHA',
#   'GAME_DATE': '2022-10-29T00:00:00',
#   'MATCHUP': 'CHA vs. GSW',
#   'OFF_RATING': 113.2,
#   'DEF_RATING': 106.6,
#   'PTS': 120,
#   'poss': 106.0},
#  {'TEAM_ABBREVIATION': 'GSW',
#   'GAME_DATE': '2022-10-29T00:00:00',
#   'MATCHUP': 'GSW @ CHA',
#   'OFF_RATING': 106.6,
#   'DEF_RATING': 113.2,
#   'PTS': 113,
#   'poss': 106.0},
#  {'TEAM_ABBREVIATION': 'ATL',
#   'GAME_DATE': '2022-10-29T00:00:00',
#   'MATCHUP': 'ATL @ MIL',
#   'OFF_RATING': 113.9,
#   'DEF_RATING': 121.8,
#   'PTS': 115,
#   'poss': 101.0},
#  {'TEAM_ABBREVIATION': 'SAC',
#   'GAME_DATE': '2022-10-29T00:00:00',
#   'MATCHUP': 'SAC vs. MIA',
#   'OFF_RATING': 119.0,
#   'DEF_RATING': 110.8,
#   'PTS': 119,
#   'poss': 100.0},
#  {'TEAM_ABBREVIATION': 'OKC',
#   'GAME_DATE': '2022-10-29T00:00:00',
#   'MATCHUP': 'OKC @ DAL',
#   'OFF_RATING': 109.3,
#   'DEF_RATING': 101.8,
#   'PTS': 117,
#   'poss': 107.0},
#  {'TEAM_ABBREVIATION': 'BKN',
#   'GAME_DATE': '2022-10-29T00:00:00',
#   'MATCHUP': 'BKN vs. IND',
#   'OFF_RATING': 120.8,
#   'DEF_RATING': 128.9,
#   'PTS': 116,
#   'poss': 96.0},
#  {'TEAM_ABBREVIATION': 'MEM',
#   'GAME_DATE': '2022-10-29T00:00:00',
#   'MATCHUP': 'MEM @ UTA',
#   'OFF_RATING': 118.3,
#   'DEF_RATING': 121.6,
#   'PTS': 123,
#   'poss': 104.0},
#  {'TEAM_ABBREVIATION': 'UTA',
#   'GAME_DATE': '2022-10-29T00:00:00',
#   'MATCHUP': 'UTA vs. MEM',
#   'OFF_RATING': 121.6,
#   'DEF_RATING': 118.3,
#   'PTS': 124,
#   'poss': 102.0},
#  {'TEAM_ABBREVIATION': 'PHI',
#   'GAME_DATE': '2022-10-29T00:00:00',
#   'MATCHUP': 'PHI @ CHI',
#   'OFF_RATING': 112.9,
#   'DEF_RATING': 106.9,
#   'PTS': 114,
#   'poss': 101.0},
#  {'TEAM_ABBREVIATION': 'DET',
#   'GAME_DATE': '2022-10-28T00:00:00',
#   'MATCHUP': 'DET vs. ATL',
#   'OFF_RATING': 113.1,
#   'DEF_RATING': 138.8,
#   'PTS': 112,
#   'poss': 99.0},
#  {'TEAM_ABBREVIATION': 'SAS',
#   'GAME_DATE': '2022-10-28T00:00:00',
#   'MATCHUP': 'SAS vs. CHI',
#   'OFF_RATING': 121.7,
#   'DEF_RATING': 117.0,
#   'PTS': 129,
#   'poss': 106.0},
#  {'TEAM_ABBREVIATION': 'ATL',
#   'GAME_DATE': '2022-10-28T00:00:00',
#   'MATCHUP': 'ATL @ DET',
#   'OFF_RATING': 138.8,
#   'DEF_RATING': 113.1,
#   'PTS': 136,
#   'poss': 98.0},
#  {'TEAM_ABBREVIATION': 'ORL',
#   'GAME_DATE': '2022-10-28T00:00:00',
#   'MATCHUP': 'ORL vs. CHA',
#   'OFF_RATING': 111.9,
#   'DEF_RATING': 93.0,
#   'PTS': 113,
#   'poss': 101.0},
#  {'TEAM_ABBREVIATION': 'POR',
#   'GAME_DATE': '2022-10-28T00:00:00',
#   'MATCHUP': 'POR vs. HOU',
#   'OFF_RATING': 123.8,
#   'DEF_RATING': 107.8,
#   'PTS': 125,
#   'poss': 101.0},
#  {'TEAM_ABBREVIATION': 'NYK',
#   'GAME_DATE': '2022-10-28T00:00:00',
#   'MATCHUP': 'NYK @ MIL',
#   'OFF_RATING': 103.8,
#   'DEF_RATING': 114.4,
#   'PTS': 108,
#   'poss': 104.0},
#  {'TEAM_ABBREVIATION': 'CLE',
#   'GAME_DATE': '2022-10-28T00:00:00',
#   'MATCHUP': 'CLE @ BOS',
#   'OFF_RATING': 121.1,
#   'DEF_RATING': 112.8,
#   'PTS': 132,
#   'poss': 109.0},
#  {'TEAM_ABBREVIATION': 'NOP',
#   'GAME_DATE': '2022-10-28T00:00:00',
#   'MATCHUP': 'NOP @ PHX',
#   'OFF_RATING': 112.1,
#   'DEF_RATING': 125.3,
#   'PTS': 111,
#   'poss': 99.0},
#  {'TEAM_ABBREVIATION': 'PHI',
#   'GAME_DATE': '2022-10-28T00:00:00',
#   'MATCHUP': 'PHI @ TOR',
#   'OFF_RATING': 120.4,
#   'DEF_RATING': 97.8,
#   'PTS': 112,
#   'poss': 93.0},
#  {'TEAM_ABBREVIATION': 'CHA',
#   'GAME_DATE': '2022-10-28T00:00:00',
#   'MATCHUP': 'CHA @ ORL',
#   'OFF_RATING': 93.0,
#   'DEF_RATING': 111.9,
#   'PTS': 93,
#   'poss': 100.0},
#  {'TEAM_ABBREVIATION': 'MIL',
#   'GAME_DATE': '2022-10-28T00:00:00',
#   'MATCHUP': 'MIL vs. NYK',
#   'OFF_RATING': 114.4,
#   'DEF_RATING': 103.8,
#   'PTS': 119,
#   'poss': 104.0},
#  {'TEAM_ABBREVIATION': 'TOR',
#   'GAME_DATE': '2022-10-28T00:00:00',
#   'MATCHUP': 'TOR vs. PHI',
#   'OFF_RATING': 97.8,
#   'DEF_RATING': 120.4,
#   'PTS': 90,
#   'poss': 92.0},
#  {'TEAM_ABBREVIATION': 'WAS',
#   'GAME_DATE': '2022-10-28T00:00:00',
#   'MATCHUP': 'WAS vs. IND',
#   'OFF_RATING': 115.8,
#   'DEF_RATING': 125.7,
#   'PTS': 117,
#   'poss': 101.0},
#  {'TEAM_ABBREVIATION': 'LAL',
#   'GAME_DATE': '2022-10-28T00:00:00',
#   'MATCHUP': 'LAL @ MIN',
#   'OFF_RATING': 93.6,
#   'DEF_RATING': 102.8,
#   'PTS': 102,
#   'poss': 109.0},
#  {'TEAM_ABBREVIATION': 'PHX',
#   'GAME_DATE': '2022-10-28T00:00:00',
#   'MATCHUP': 'PHX vs. NOP',
#   'OFF_RATING': 125.3,
#   'DEF_RATING': 112.1,
#   'PTS': 124,
#   'poss': 99.0},
#  {'TEAM_ABBREVIATION': 'IND',
#   'GAME_DATE': '2022-10-28T00:00:00',
#   'MATCHUP': 'IND @ WAS',
#   'OFF_RATING': 125.7,
#   'DEF_RATING': 115.8,
#   'PTS': 127,
#   'poss': 101.0},
#  {'TEAM_ABBREVIATION': 'MIN',
#   'GAME_DATE': '2022-10-28T00:00:00',
#   'MATCHUP': 'MIN vs. LAL',
#   'OFF_RATING': 102.8,
#   'DEF_RATING': 93.6,
#   'PTS': 111,
#   'poss': 108.0},
#  {'TEAM_ABBREVIATION': 'UTA',
#   'GAME_DATE': '2022-10-28T00:00:00',
#   'MATCHUP': 'UTA @ DEN',
#   'OFF_RATING': 106.3,
#   'DEF_RATING': 120.6,
#   'PTS': 101,
#   'poss': 95.0},
#  {'TEAM_ABBREVIATION': 'CHI',
#   'GAME_DATE': '2022-10-28T00:00:00',
#   'MATCHUP': 'CHI @ SAS',
#   'OFF_RATING': 117.0,
#   'DEF_RATING': 121.7,
#   'PTS': 124,
#   'poss': 106.0},
#  {'TEAM_ABBREVIATION': 'DEN',
#   'GAME_DATE': '2022-10-28T00:00:00',
#   'MATCHUP': 'DEN vs. UTA',
#   'OFF_RATING': 120.6,
#   'DEF_RATING': 106.3,
#   'PTS': 117,
#   'poss': 97.0},
#  {'TEAM_ABBREVIATION': 'BOS',
#   'GAME_DATE': '2022-10-28T00:00:00',
#   'MATCHUP': 'BOS vs. CLE',
#   'OFF_RATING': 112.8,
# ...
#   'GAME_DATE': '2022-10-21T00:00:00',
#   'MATCHUP': 'DET @ NYK',
#   'OFF_RATING': 101.9,
#   'DEF_RATING': 125.0,
#   'PTS': 106,
#   'poss': 104.0},
#  {'TEAM_ABBREVIATION': 'WAS',
#   'GAME_DATE': '2022-10-21T00:00:00',
#   'MATCHUP': 'WAS vs. CHI',
#   'OFF_RATING': 103.0,
#   'DEF_RATING': 103.1,
#   'PTS': 102,
#   'poss': 99.0},
#  {'TEAM_ABBREVIATION': 'POR',
#   'GAME_DATE': '2022-10-21T00:00:00',
#   'MATCHUP': 'POR vs. PHX',
#   'OFF_RATING': 103.7,
#   'DEF_RATING': 102.8,
#   'PTS': 113,
#   'poss': 109.0},
#  {'TEAM_ABBREVIATION': 'MIA',
#   'GAME_DATE': '2022-10-21T00:00:00',
#   'MATCHUP': 'MIA vs. BOS',
#   'OFF_RATING': 109.5,
#   'DEF_RATING': 116.8,
#   'PTS': 104,
#   'poss': 95.0},
#  {'TEAM_ABBREVIATION': 'HOU',
#   'GAME_DATE': '2022-10-21T00:00:00',
#   'MATCHUP': 'HOU vs. MEM',
#   'OFF_RATING': 118.4,
#   'DEF_RATING': 126.5,
#   'PTS': 122,
#   'poss': 103.0},
#  {'TEAM_ABBREVIATION': 'MIL',
#   'GAME_DATE': '2022-10-20T00:00:00',
#   'MATCHUP': 'MIL @ PHI',
#   'OFF_RATING': 94.7,
#   'DEF_RATING': 92.6,
#   'PTS': 90,
#   'poss': 95.0},
#  {'TEAM_ABBREVIATION': 'PHI',
#   'GAME_DATE': '2022-10-20T00:00:00',
#   'MATCHUP': 'PHI vs. MIL',
#   'OFF_RATING': 92.6,
#   'DEF_RATING': 94.7,
#   'PTS': 88,
#   'poss': 95.0},
#  {'TEAM_ABBREVIATION': 'LAC',
#   'GAME_DATE': '2022-10-20T00:00:00',
#   'MATCHUP': 'LAC @ LAL',
#   'OFF_RATING': 99.0,
#   'DEF_RATING': 91.5,
#   'PTS': 103,
#   'poss': 104.0},
#  {'TEAM_ABBREVIATION': 'LAL',
#   'GAME_DATE': '2022-10-20T00:00:00',
#   'MATCHUP': 'LAL vs. LAC',
#   'OFF_RATING': 91.5,
#   'DEF_RATING': 99.0,
#   'PTS': 97,
#   'poss': 106.0},
#  {'TEAM_ABBREVIATION': 'HOU',
#   'GAME_DATE': '2022-10-19T00:00:00',
#   'MATCHUP': 'HOU @ ATL',
#   'OFF_RATING': 100.9,
#   'DEF_RATING': 110.4,
#   'PTS': 107,
#   'poss': 106.0},
#  {'TEAM_ABBREVIATION': 'ATL',
#   'GAME_DATE': '2022-10-19T00:00:00',
#   'MATCHUP': 'ATL vs. HOU',
#   'OFF_RATING': 110.4,
#   'DEF_RATING': 100.9,
#   'PTS': 117,
#   'poss': 106.0},
#  {'TEAM_ABBREVIATION': 'MIA',
#   'GAME_DATE': '2022-10-19T00:00:00',
#   'MATCHUP': 'MIA vs. CHI',
#   'OFF_RATING': 102.9,
#   'DEF_RATING': 110.5,
#   'PTS': 108,
#   'poss': 105.0},
#  {'TEAM_ABBREVIATION': 'PHX',
#   'GAME_DATE': '2022-10-19T00:00:00',
#   'MATCHUP': 'PHX vs. DAL',
#   'OFF_RATING': 113.8,
#   'DEF_RATING': 110.5,
#   'PTS': 107,
#   'poss': 94.0},
#  {'TEAM_ABBREVIATION': 'SAC',
#   'GAME_DATE': '2022-10-19T00:00:00',
#   'MATCHUP': 'SAC vs. POR',
#   'OFF_RATING': 106.9,
#   'DEF_RATING': 113.9,
#   'PTS': 108,
#   'poss': 101.0},
#  {'TEAM_ABBREVIATION': 'OKC',
#   'GAME_DATE': '2022-10-19T00:00:00',
#   'MATCHUP': 'OKC @ MIN',
#   'OFF_RATING': 100.9,
#   'DEF_RATING': 109.5,
#   'PTS': 108,
#   'poss': 107.0},
#  {'TEAM_ABBREVIATION': 'IND',
#   'GAME_DATE': '2022-10-19T00:00:00',
#   'MATCHUP': 'IND vs. WAS',
#   'OFF_RATING': 102.9,
#   'DEF_RATING': 108.6,
#   'PTS': 107,
#   'poss': 104.0},
#  {'TEAM_ABBREVIATION': 'CHA',
#   'GAME_DATE': '2022-10-19T00:00:00',
#   'MATCHUP': 'CHA @ SAS',
#   'OFF_RATING': 120.6,
#   'DEF_RATING': 97.1,
#   'PTS': 129,
#   'poss': 107.0},
#  {'TEAM_ABBREVIATION': 'SAS',
#   'GAME_DATE': '2022-10-19T00:00:00',
#   'MATCHUP': 'SAS vs. CHA',
#   'OFF_RATING': 97.1,
#   'DEF_RATING': 120.6,
#   'PTS': 102,
#   'poss': 105.0},
#  {'TEAM_ABBREVIATION': 'CHI',
#   'GAME_DATE': '2022-10-19T00:00:00',
#   'MATCHUP': 'CHI @ MIA',
#   'OFF_RATING': 110.5,
#   'DEF_RATING': 102.9,
#   'PTS': 116,
#   'poss': 105.0},
#  {'TEAM_ABBREVIATION': 'TOR',
#   'GAME_DATE': '2022-10-19T00:00:00',
#   'MATCHUP': 'TOR vs. CLE',
#   'OFF_RATING': 109.1,
#   'DEF_RATING': 106.1,
#   'PTS': 108,
#   'poss': 99.0},
#  {'TEAM_ABBREVIATION': 'UTA',
#   'GAME_DATE': '2022-10-19T00:00:00',
#   'MATCHUP': 'UTA vs. DEN',
#   'OFF_RATING': 119.4,
#   'DEF_RATING': 100.0,
#   'PTS': 123,
#   'poss': 103.0},
#  {'TEAM_ABBREVIATION': 'DAL',
#   'GAME_DATE': '2022-10-19T00:00:00',
#   'MATCHUP': 'DAL @ PHX',
#   'OFF_RATING': 110.5,
#   'DEF_RATING': 113.8,
#   'PTS': 105,
#   'poss': 95.0},
#  {'TEAM_ABBREVIATION': 'NOP',
#   'GAME_DATE': '2022-10-19T00:00:00',
#   'MATCHUP': 'NOP @ BKN',
#   'OFF_RATING': 127.5,
#   'DEF_RATING': 105.9,
#   'PTS': 130,
#   'poss': 102.0},
#  {'TEAM_ABBREVIATION': 'NYK',
#   'GAME_DATE': '2022-10-19T00:00:00',
#   'MATCHUP': 'NYK @ MEM',
#   'OFF_RATING': 105.7,
#   'DEF_RATING': 107.5,
#   'PTS': 112,
#   'poss': 106.0},
#  {'TEAM_ABBREVIATION': 'DET',
#   'GAME_DATE': '2022-10-19T00:00:00',
#   'MATCHUP': 'DET vs. ORL',
#   'OFF_RATING': 111.9,
#   'DEF_RATING': 106.9,
#   'PTS': 113,
#   'poss': 101.0},
#  {'TEAM_ABBREVIATION': 'DEN',
#   'GAME_DATE': '2022-10-19T00:00:00',
#   'MATCHUP': 'DEN @ UTA',
#   'OFF_RATING': 100.0,
#   'DEF_RATING': 119.4,
#   'PTS': 102,
#   'poss': 102.0},
#  {'TEAM_ABBREVIATION': 'CLE',
#   'GAME_DATE': '2022-10-19T00:00:00',
#   'MATCHUP': 'CLE @ TOR',
#   'OFF_RATING': 106.1,
#   'DEF_RATING': 109.1,
#   'PTS': 105,
#   'poss': 99.0},
#  {'TEAM_ABBREVIATION': 'ORL',
#   'GAME_DATE': '2022-10-19T00:00:00',
#   'MATCHUP': 'ORL @ DET',
#   'OFF_RATING': 106.9,
#   'DEF_RATING': 111.9,
#   'PTS': 109,
#   'poss': 102.0},
#  {'TEAM_ABBREVIATION': 'MEM',
#   'GAME_DATE': '2022-10-19T00:00:00',
#   'MATCHUP': 'MEM vs. NYK',
#   'OFF_RATING': 107.5,
#   'DEF_RATING': 105.7,
#   'PTS': 115,
#   'poss': 107.0},
#  {'TEAM_ABBREVIATION': 'BKN',
#   'GAME_DATE': '2022-10-19T00:00:00',
#   'MATCHUP': 'BKN vs. NOP',
#   'OFF_RATING': 105.9,
#   'DEF_RATING': 127.5,
#   'PTS': 108,
#   'poss': 102.0},
#  {'TEAM_ABBREVIATION': 'MIN',
#   'GAME_DATE': '2022-10-19T00:00:00',
#   'MATCHUP': 'MIN vs. OKC',
#   'OFF_RATING': 109.5,
#   'DEF_RATING': 100.9,
#   'PTS': 115,
#   'poss': 105.0},
#  {'TEAM_ABBREVIATION': 'POR',
#   'GAME_DATE': '2022-10-19T00:00:00',
#   'MATCHUP': 'POR @ SAC',
#   'OFF_RATING': 113.9,
#   'DEF_RATING': 106.9,
#   'PTS': 115,
#   'poss': 101.0},
#  {'TEAM_ABBREVIATION': 'WAS',
#   'GAME_DATE': '2022-10-19T00:00:00',
#   'MATCHUP': 'WAS @ IND',
#   'OFF_RATING': 108.6,
#   'DEF_RATING': 102.9,
#   'PTS': 114,
#   'poss': 105.0},
#  {'TEAM_ABBREVIATION': 'LAL',
#   'GAME_DATE': '2022-10-18T00:00:00',
#   'MATCHUP': 'LAL @ GSW',
#   'OFF_RATING': 97.3,
#   'DEF_RATING': 107.0,
#   'PTS': 109,
#   'poss': 112.0},
#  {'TEAM_ABBREVIATION': 'GSW',
#   'GAME_DATE': '2022-10-18T00:00:00',
#   'MATCHUP': 'GSW vs. LAL',
#   'OFF_RATING': 107.0,
#   'DEF_RATING': 97.3,
#   'PTS': 123,
#   'poss': 115.0},
#  {'TEAM_ABBREVIATION': 'BOS',
#   'GAME_DATE': '2022-10-18T00:00:00',
#   'MATCHUP': 'BOS vs. PHI',
#   'OFF_RATING': 129.9,
#   'DEF_RATING': 119.4,
#   'PTS': 126,
#   'poss': 97.0},
#  {'TEAM_ABBREVIATION': 'PHI',
#   'GAME_DATE': '2022-10-18T00:00:00',
#   'MATCHUP': 'PHI @ BOS',
#   'OFF_RATING': 119.4,
#   'DEF_RATING': 129.9,
#   'PTS': 117,
#   'poss': 98.0},
#  {'TEAM_ABBREVIATION': 'DAL',
#   'GAME_DATE': '2022-11-16T00:00:00',
#   'MATCHUP': 'DAL vs. HOU',
#   'OFF_RATING': 93.9,
#   'DEF_RATING': 103.1,
#   'PTS': 92,
#   'poss': 98.0},
#  {'TEAM_ABBREVIATION': 'MIA',
#   'GAME_DATE': '2022-11-16T00:00:00',
#   'MATCHUP': 'MIA @ TOR',
#   'OFF_RATING': 111.8,
#   'DEF_RATING': 119.1,
#   'PTS': 104,
#   'poss': 93.0},
#  {'TEAM_ABBREVIATION': 'GSW',
#   'GAME_DATE': '2022-11-16T00:00:00',
#   'MATCHUP': 'GSW @ PHX',
#   'OFF_RATING': 111.2,
#   'DEF_RATING': 121.5,
#   'PTS': 119,
#   'poss': 107.0},
#  {'TEAM_ABBREVIATION': 'DEN',
#   'GAME_DATE': '2022-11-16T00:00:00',
#   'MATCHUP': 'DEN vs. NYK',
#   'OFF_RATING': 109.6,
#   'DEF_RATING': 112.8,
#   'PTS': 103,
#   'poss': 94.0},
#  {'TEAM_ABBREVIATION': 'CHA',
#   'GAME_DATE': '2022-11-16T00:00:00',
#   'MATCHUP': 'CHA vs. IND',
#   'OFF_RATING': 107.6,
#   'DEF_RATING': 120.2,
#   'PTS': 113,
#   'poss': 105.0},
#  {'TEAM_ABBREVIATION': 'WAS',
#   'GAME_DATE': '2022-11-16T00:00:00',
#   'MATCHUP': 'WAS vs. OKC',
#   'OFF_RATING': 118.8,
#   'DEF_RATING': 119.8,
#   'PTS': 120,
#   'poss': 101.0},
#  {'TEAM_ABBREVIATION': 'OKC',
#   'GAME_DATE': '2022-11-16T00:00:00',
#   'MATCHUP': 'OKC @ WAS',
#   'OFF_RATING': 119.8,
#   'DEF_RATING': 118.8,
#   'PTS': 121,
#   'poss': 101.0},
#  {'TEAM_ABBREVIATION': 'CHI',
#   'GAME_DATE': '2022-11-16T00:00:00',
#   'MATCHUP': 'CHI @ NOP',
#   'OFF_RATING': 111.1,
#   'DEF_RATING': 126.5,
#   'PTS': 110,
#   'poss': 99.0},
#  {'TEAM_ABBREVIATION': 'NYK',
#   'GAME_DATE': '2022-11-16T00:00:00',
#   'MATCHUP': 'NYK @ DEN',
#   'OFF_RATING': 112.8,
#   'DEF_RATING': 109.6,
#   'PTS': 106,
#   'poss': 94.0},
#  {'TEAM_ABBREVIATION': 'CLE',
#   'GAME_DATE': '2022-11-16T00:00:00',
#   'MATCHUP': 'CLE @ MIL',
#   'OFF_RATING': 103.2,
#   'DEF_RATING': 120.2,
#   'PTS': 98,
#   'poss': 95.0},
#  {'TEAM_ABBREVIATION': 'ORL',
#   'GAME_DATE': '2022-11-16T00:00:00',
#   'MATCHUP': 'ORL vs. MIN',
#   'OFF_RATING': 106.9,
#   'DEF_RATING': 124.8,
#   'PTS': 108,
#   'poss': 101.0},
#  {'TEAM_ABBREVIATION': 'TOR',
#   'GAME_DATE': '2022-11-16T00:00:00',
#   'MATCHUP': 'TOR vs. MIA',
#   'OFF_RATING': 119.1,
#   'DEF_RATING': 111.8,
#   'PTS': 112,
#   'poss': 94.0},
#  {'TEAM_ABBREVIATION': 'HOU',
#   'GAME_DATE': '2022-11-16T00:00:00',
#   'MATCHUP': 'HOU @ DAL',
#   'OFF_RATING': 103.1,
#   'DEF_RATING': 93.9,
#   'PTS': 101,
#   'poss': 98.0},
#  {'TEAM_ABBREVIATION': 'ATL',
#   'GAME_DATE': '2022-11-16T00:00:00',
#   'MATCHUP': 'ATL vs. BOS',
#   'OFF_RATING': 98.1,
#   'DEF_RATING': 124.8,
#   'PTS': 101,
#   'poss': 103.0},
#  {'TEAM_ABBREVIATION': 'PHX',
#   'GAME_DATE': '2022-11-16T00:00:00',
#   'MATCHUP': 'PHX vs. GSW',
#   'OFF_RATING': 121.5,
#   'DEF_RATING': 111.2,
#   'PTS': 130,
#   'poss': 107.0},
#  {'TEAM_ABBREVIATION': 'IND',
#   'GAME_DATE': '2022-11-16T00:00:00',
#   'MATCHUP': 'IND @ CHA',
#   'OFF_RATING': 120.2,
#   'DEF_RATING': 107.6,
#   'PTS': 125,
#   'poss': 104.0},
#  {'TEAM_ABBREVIATION': 'NOP',
#   'GAME_DATE': '2022-11-16T00:00:00',
#   'MATCHUP': 'NOP vs. CHI',
#   'OFF_RATING': 126.5,
#   'DEF_RATING': 111.1,
#   'PTS': 124,
#   'poss': 98.0},
#  {'TEAM_ABBREVIATION': 'MIL',
#   'GAME_DATE': '2022-11-16T00:00:00',
#   'MATCHUP': 'MIL vs. CLE',
#   'OFF_RATING': 120.2,
#   'DEF_RATING': 103.2,
#   'PTS': 113,
#   'poss': 94.0},
#  {'TEAM_ABBREVIATION': 'MIN',
#   'GAME_DATE': '2022-11-16T00:00:00',
#   'MATCHUP': 'MIN @ ORL',
#   'OFF_RATING': 124.8,
#   'DEF_RATING': 106.9,
#   'PTS': 126,
#   'poss': 101.0},
#  {'TEAM_ABBREVIATION': 'BOS',
#   'GAME_DATE': '2022-11-16T00:00:00',
#   'MATCHUP': 'BOS @ ATL',
#   'OFF_RATING': 124.8,
#   'DEF_RATING': 98.1,
#   'PTS': 126,
#   'poss': 101.0},
#  {'TEAM_ABBREVIATION': 'MEM',
#   'GAME_DATE': '2022-11-15T00:00:00',
#   'MATCHUP': 'MEM @ NOP',
#   'OFF_RATING': 103.0,
#   'DEF_RATING': 115.3,
#   'PTS': 102,
#   'poss': 99.0},
#  {'TEAM_ABBREVIATION': 'BKN',
#   'GAME_DATE': '2022-11-15T00:00:00',
#   'MATCHUP': 'BKN @ SAC',
#   'OFF_RATING': 111.0,
#   'DEF_RATING': 140.4,
#   'PTS': 121,
#   'poss': 109.0},
#  {'TEAM_ABBREVIATION': 'SAS',
#   'GAME_DATE': '2022-11-15T00:00:00',
#   'MATCHUP': 'SAS @ POR',
#   'OFF_RATING': 112.2,
#   'DEF_RATING': 120.6,
#   'PTS': 110,
#   'poss': 98.0},
#  {'TEAM_ABBREVIATION': 'UTA',
#   'GAME_DATE': '2022-11-15T00:00:00',
#   'MATCHUP': 'UTA vs. NYK',
#   'OFF_RATING': 107.8,
#   'DEF_RATING': 114.6,
#   'PTS': 111,
#   'poss': 103.0},
#  {'TEAM_ABBREVIATION': 'LAC',
#   'GAME_DATE': '2022-11-15T00:00:00',
#   'MATCHUP': 'LAC @ DAL',
#   'OFF_RATING': 106.3,
#   'DEF_RATING': 109.6,
#   'PTS': 101,
#   'poss': 95.0},
#  {'TEAM_ABBREVIATION': 'DAL',
#   'GAME_DATE': '2022-11-15T00:00:00',
#   'MATCHUP': 'DAL vs. LAC',
#   'OFF_RATING': 109.6,
#   'DEF_RATING': 106.3,
#   'PTS': 103,
#   'poss': 94.0},
#  {'TEAM_ABBREVIATION': 'POR',
#   'GAME_DATE': '2022-11-15T00:00:00',
#   'MATCHUP': 'POR vs. SAS',
#   'OFF_RATING': 120.6,
#   'DEF_RATING': 112.2,
#   'PTS': 117,
#   'poss': 97.0},
#  {'TEAM_ABBREVIATION': 'NYK',
#   'GAME_DATE': '2022-11-15T00:00:00',
#   'MATCHUP': 'NYK @ UTA',
#   'OFF_RATING': 114.6,
#   'DEF_RATING': 107.8,
#   'PTS': 118,
#   'poss': 103.0},
#  {'TEAM_ABBREVIATION': 'NOP',
#   'GAME_DATE': '2022-11-15T00:00:00',
#   'MATCHUP': 'NOP vs. MEM',
#   'OFF_RATING': 115.3,
#   'DEF_RATING': 103.0,
#   'PTS': 113,
#   'poss': 98.0},
#  {'TEAM_ABBREVIATION': 'SAC',
#   'GAME_DATE': '2022-11-15T00:00:00',
#   'MATCHUP': 'SAC vs. BKN',
#   'OFF_RATING': 140.4,
#   'DEF_RATING': 111.0,
#   'PTS': 153,
#   'poss': 109.0},
#  {'TEAM_ABBREVIATION': 'SAC',
#   'GAME_DATE': '2022-11-17T00:00:00',
#   'MATCHUP': 'SAC vs. SAS',
#   'OFF_RATING': 131.3,
#   'DEF_RATING': 113.1,
#   'PTS': 130,
#   'poss': 99.0},
#  {'TEAM_ABBREVIATION': 'SAS',
#   'GAME_DATE': '2022-11-17T00:00:00',
#   'MATCHUP': 'SAS @ SAC',
#   'OFF_RATING': 113.1,
#   'DEF_RATING': 131.3,
#   'PTS': 112,
#   'poss': 99.0},
#  {'TEAM_ABBREVIATION': 'LAC',
#   'GAME_DATE': '2022-11-17T00:00:00',
#   'MATCHUP': 'LAC vs. DET',
#   'OFF_RATING': 99.0,
#   'DEF_RATING': 93.8,
#   'PTS': 96,
#   'poss': 97.0},
#  {'TEAM_ABBREVIATION': 'BKN',
#   'GAME_DATE': '2022-11-17T00:00:00',
#   'MATCHUP': 'BKN @ POR',
#   'OFF_RATING': 109.0,
#   'DEF_RATING': 107.0,
#   'PTS': 109,
#   'poss': 100.0},
#  {'TEAM_ABBREVIATION': 'DET',
#   'GAME_DATE': '2022-11-17T00:00:00',
#   'MATCHUP': 'DET @ LAC',
#   'OFF_RATING': 93.8,
#   'DEF_RATING': 99.0,
#   'PTS': 91,
#   'poss': 97.0},
#  {'TEAM_ABBREVIATION': 'POR',
#   'GAME_DATE': '2022-11-17T00:00:00',
#   'MATCHUP': 'POR vs. BKN',
#   'OFF_RATING': 107.0,
#   'DEF_RATING': 109.0,
#   'PTS': 107,
#   'poss': 100.0},
#  {'TEAM_ABBREVIATION': 'ATL',
#   'GAME_DATE': '2022-11-16T00:00:00',
#   'MATCHUP': 'ATL vs. BOS',
#   'OFF_RATING': 98.1,
#   'DEF_RATING': 124.8,
#   'PTS': 101,
#   'poss': 103.0},
#  {'TEAM_ABBREVIATION': 'ORL',
#   'GAME_DATE': '2022-11-16T00:00:00',
#   'MATCHUP': 'ORL vs. MIN',
#   'OFF_RATING': 106.9,
#   'DEF_RATING': 124.8,
#   'PTS': 108,
#   'poss': 101.0},
#  {'TEAM_ABBREVIATION': 'CLE',
#   'GAME_DATE': '2022-11-16T00:00:00',
#   'MATCHUP': 'CLE @ MIL',
#   'OFF_RATING': 103.2,
#   'DEF_RATING': 120.2,
#   'PTS': 98,
#   'poss': 95.0},
#  {'TEAM_ABBREVIATION': 'CHI',
#   'GAME_DATE': '2022-11-16T00:00:00',
#   'MATCHUP': 'CHI @ NOP',
#   'OFF_RATING': 111.1,
#   'DEF_RATING': 126.5,
#   'PTS': 110,
#   'poss': 99.0},
#  {'TEAM_ABBREVIATION': 'CHA',
#   'GAME_DATE': '2022-11-16T00:00:00',
#   'MATCHUP': 'CHA vs. IND',
#   'OFF_RATING': 107.6,
#   'DEF_RATING': 120.2,
#   'PTS': 113,
#   'poss': 105.0},
#  {'TEAM_ABBREVIATION': 'GSW',
#   'GAME_DATE': '2022-11-16T00:00:00',
#   'MATCHUP': 'GSW @ PHX',
#   'OFF_RATING': 111.2,
#   'DEF_RATING': 121.5,
#   'PTS': 119,
#   'poss': 107.0},
#  {'TEAM_ABBREVIATION': 'DAL',
#   'GAME_DATE': '2022-11-16T00:00:00',
#   'MATCHUP': 'DAL vs. HOU',
#   'OFF_RATING': 93.9,
#   'DEF_RATING': 103.1,
#   'PTS': 92,
#   'poss': 98.0},
#  {'TEAM_ABBREVIATION': 'MIA',
#   'GAME_DATE': '2022-11-16T00:00:00',
#   'MATCHUP': 'MIA @ TOR',
#   'OFF_RATING': 111.8,
#   'DEF_RATING': 119.1,
#   'PTS': 104,
#   'poss': 93.0},
#  {'TEAM_ABBREVIATION': 'DEN',
#   'GAME_DATE': '2022-11-16T00:00:00',
#   'MATCHUP': 'DEN vs. NYK',
#   'OFF_RATING': 109.6,
#   'DEF_RATING': 112.8,
#   'PTS': 103,
#   'poss': 94.0},
#  {'TEAM_ABBREVIATION': 'WAS',
#   'GAME_DATE': '2022-11-16T00:00:00',
#   'MATCHUP': 'WAS vs. OKC',
#   'OFF_RATING': 118.8,
#   'DEF_RATING': 119.8,
#   'PTS': 120,
#   'poss': 101.0},
#  {'TEAM_ABBREVIATION': 'OKC',
#   'GAME_DATE': '2022-11-16T00:00:00',
#   'MATCHUP': 'OKC @ WAS',
#   'OFF_RATING': 119.8,
#   'DEF_RATING': 118.8,
#   'PTS': 121,
#   'poss': 101.0},
#  {'TEAM_ABBREVIATION': 'NYK',
#   'GAME_DATE': '2022-11-16T00:00:00',
#   'MATCHUP': 'NYK @ DEN',
#   'OFF_RATING': 112.8,
#   'DEF_RATING': 109.6,
#   'PTS': 106,
#   'poss': 94.0},
#  {'TEAM_ABBREVIATION': 'TOR',
#   'GAME_DATE': '2022-11-16T00:00:00',
#   'MATCHUP': 'TOR vs. MIA',
#   'OFF_RATING': 119.1,
#   'DEF_RATING': 111.8,
#   'PTS': 112,
#   'poss': 94.0},
#  {'TEAM_ABBREVIATION': 'HOU',
#   'GAME_DATE': '2022-11-16T00:00:00',
#   'MATCHUP': 'HOU @ DAL',
#   'OFF_RATING': 103.1,
#   'DEF_RATING': 93.9,
#   'PTS': 101,
#   'poss': 98.0},
#  {'TEAM_ABBREVIATION': 'PHX',
#   'GAME_DATE': '2022-11-16T00:00:00',
#   'MATCHUP': 'PHX vs. GSW',
#   'OFF_RATING': 121.5,
#   'DEF_RATING': 111.2,
#   'PTS': 130,
#   'poss': 107.0},
#  {'TEAM_ABBREVIATION': 'IND',
#   'GAME_DATE': '2022-11-16T00:00:00',
#   'MATCHUP': 'IND @ CHA',
#   'OFF_RATING': 120.2,
#   'DEF_RATING': 107.6,
#   'PTS': 125,
#   'poss': 104.0},
#  {'TEAM_ABBREVIATION': 'NOP',
#   'GAME_DATE': '2022-11-16T00:00:00',
#   'MATCHUP': 'NOP vs. CHI',
#   'OFF_RATING': 126.5,
#   'DEF_RATING': 111.1,
#   'PTS': 124,
#   'poss': 98.0},
#  {'TEAM_ABBREVIATION': 'MIL',
#   'GAME_DATE': '2022-11-16T00:00:00',
#   'MATCHUP': 'MIL vs. CLE',
#   'OFF_RATING': 120.2,
#   'DEF_RATING': 103.2,
#   'PTS': 113,
#   'poss': 94.0},
#  {'TEAM_ABBREVIATION': 'MIN',
#   'GAME_DATE': '2022-11-16T00:00:00',
#   'MATCHUP': 'MIN @ ORL',
#   'OFF_RATING': 124.8,
#   'DEF_RATING': 106.9,
#   'PTS': 126,
#   'poss': 101.0},
#  {'TEAM_ABBREVIATION': 'BOS',
#   'GAME_DATE': '2022-11-16T00:00:00',
#   'MATCHUP': 'BOS @ ATL',
#   'OFF_RATING': 124.8,
#   'DEF_RATING': 98.1,
#   'PTS': 126,
#   'poss': 101.0}]

# %%
(112.5/100) / 126
# Out:
# 0.008928571428571428

# %%
112.5/126
# Out:
# 0.8928571428571429
